# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Retina mode
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import torch
from torchvision import datasets, transforms
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Full Batch GD

# %%
num_samples = 40
np.random.seed(45) 

# Generate data
x1 = np.random.uniform(-20, 20, num_samples)
f_x = 100*x1 + 1
eps = np.random.randn(num_samples)
y = f_x + eps
print(x1.shape,y.shape)
# Out:
# (40,) (40,)

# %%
theta=torch.randn((2,1),requires_grad=True)

x=torch.tensor(x1,dtype=torch.float32).view(-1, 1)       #reshape is same as view
x=torch.cat((torch.ones(x.shape[0],1),x), dim=1)
y =torch.tensor(y, dtype=torch.float32).view(-1, 1)
theta_hist=[]
loss_hist=[]
learning_rate=0.001
beta = 0.08
v_t = torch.zeros_like(theta)
Epoch=0
while(True):
    Epoch+=1
    theta_old=theta.clone()
    theta_hist.append(theta_old.detach().numpy().flatten())
    y_pred=torch.matmul(x,theta)
    loss=torch.mean((y-y_pred)**2)
    loss_hist.append(loss.clone().detach().item())
    loss.backward()       # As soon as you alled the backward func in the loss it calculates the grad  of loss wrt defined var which has req_grad=True and stores in the defined var.grad
    with torch.no_grad():
        v_t = beta*v_t + (1-beta)*theta.grad
        theta-=learning_rate*v_t
        theta.grad.zero_()
        if(abs(theta_old[0]-theta[0])<0.001 and abs(theta_old[1]-theta[1])<0.001):
            break
    print(f"Step {Epoch}, theta:\n", theta)
print(Epoch) 
print(loss_hist)
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_13564\1972912448.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y =torch.tensor(y, dtype=torch.float32).view(-1, 1)
# Step 1, theta:
#  tensor([[-0.9888],
#         [22.8622]], requires_grad=True)
# Step 2, theta:
#  tensor([[-1.2504],
#         [42.6520]], requires_grad=True)
# Step 3, theta:
#  tensor([[-1.4459],
#         [57.5558]], requires_grad=True)
# Step 4, theta:
#  tensor([[-1.5894],
#         [68.6035]], requires_grad=True)
# Step 5, theta:
#  tensor([[-1.6940],
#         [76.7741]], requires_grad=True)
# Step 6, theta:
#  tensor([[-1.7699],
#         [82.8149]], requires_grad=True)
# Step 7, theta:
#  tensor([[-1.8244],
#         [87.2809]], requires_grad=True)
# Step 8, theta:
#  tensor([[-1.8633],
#         [90.5825]], requires_grad=True)
# Step 9, theta:
#  tensor([[-1.8905],
#         [93.0234]], requires_grad=True)
# Step 10, theta:
#  tensor([[-1.9092],
#         [94.8279]], requires_grad=True)
# Step 11, theta:
#  tensor([[-1.9215],
#         [96.1619]], requires_grad=True)
# Step 12, theta:
#  tensor([[-1.9291],
#         [97.1482]], requires_grad=True)
# Step 13, theta:
#  tensor([[-1.9332],
#         [97.8774]], requires_grad=True)
# Step 14, theta:
#  tensor([[-1.9348],
#         [98.4165]], requires_grad=True)
# Step 15, theta:
#  tensor([[-1.9345],
#         [98.8150]], requires_grad=True)
# Step 16, theta:
#  tensor([[-1.9328],
#         [99.1097]], requires_grad=True)
# Step 17, theta:
#  tensor([[-1.9301],
#         [99.3275]], requires_grad=True)
# Step 18, theta:
#  tensor([[-1.9266],
#         [99.4886]], requires_grad=True)
# Step 19, theta:
#  tensor([[-1.9226],
#         [99.6077]], requires_grad=True)
# Step 20, theta:
#  tensor([[-1.9182],
#         [99.6958]], requires_grad=True)
# Step 21, theta:
#  tensor([[-1.9134],
#         [99.7609]], requires_grad=True)
# Step 22, theta:
#  tensor([[-1.9085],
#         [99.8091]], requires_grad=True)
# Step 23, theta:
#  tensor([[-1.9034],
#         [99.8447]], requires_grad=True)
# Step 24, theta:
#  tensor([[-1.8981],
#         [99.8711]], requires_grad=True)
# Step 25, theta:
#  tensor([[-1.8928],
#         [99.8906]], requires_grad=True)
# Step 26, theta:
#  tensor([[-1.8875],
#         [99.9050]], requires_grad=True)
# Step 27, theta:
#  tensor([[-1.8821],
#         [99.9157]], requires_grad=True)
# Step 28, theta:
#  tensor([[-1.8766],
#         [99.9237]], requires_grad=True)
# Step 29, theta:
#  tensor([[-1.8712],
#         [99.9295]], requires_grad=True)
# Step 30, theta:
#  tensor([[-1.8657],
#         [99.9339]], requires_grad=True)
# Step 31, theta:
#  tensor([[-1.8603],
#         [99.9371]], requires_grad=True)
# Step 32, theta:
#  tensor([[-1.8548],
#         [99.9396]], requires_grad=True)
# Step 33, theta:
#  tensor([[-1.8493],
#         [99.9414]], requires_grad=True)
# Step 34, theta:
#  tensor([[-1.8439],
#         [99.9427]], requires_grad=True)
# Step 35, theta:
#  tensor([[-1.8384],
#         [99.9438]], requires_grad=True)
# Step 36, theta:
#  tensor([[-1.8330],
#         [99.9445]], requires_grad=True)
# Step 37, theta:
#  tensor([[-1.8276],
#         [99.9451]], requires_grad=True)
# Step 38, theta:
#  tensor([[-1.8221],
#         [99.9456]], requires_grad=True)
# Step 39, theta:
#  tensor([[-1.8167],
#         [99.9459]], requires_grad=True)
# Step 40, theta:
#  tensor([[-1.8113],
#         [99.9462]], requires_grad=True)
# Step 41, theta:
#  tensor([[-1.8059],
#         [99.9464]], requires_grad=True)
# Step 42, theta:
#  tensor([[-1.8005],
#         [99.9466]], requires_grad=True)
# Step 43, theta:
#  tensor([[-1.7952],
#         [99.9468]], requires_grad=True)
# Step 44, theta:
#  tensor([[-1.7898],
#         [99.9469]], requires_grad=True)
# Step 45, theta:
#  tensor([[-1.7844],
#         [99.9470]], requires_grad=True)
# Step 46, theta:
#  tensor([[-1.7791],
#         [99.9471]], requires_grad=True)
# Step 47, theta:
#  tensor([[-1.7737],
#         [99.9472]], requires_grad=True)
# Step 48, theta:
#  tensor([[-1.7684],
#         [99.9473]], requires_grad=True)
# Step 49, theta:
#  tensor([[-1.7631],
#         [99.9474]], requires_grad=True)
# Step 50, theta:
#  tensor([[-1.7578],
#         [99.9475]], requires_grad=True)
# Step 51, theta:
#  tensor([[-1.7525],
#         [99.9476]], requires_grad=True)
# Step 52, theta:
#  tensor([[-1.7472],
#         [99.9477]], requires_grad=True)
# Step 53, theta:
#  tensor([[-1.7420],
#         [99.9477]], requires_grad=True)
# Step 54, theta:
#  tensor([[-1.7367],
#         [99.9478]], requires_grad=True)
# Step 55, theta:
#  tensor([[-1.7314],
#         [99.9479]], requires_grad=True)
# Step 56, theta:
#  tensor([[-1.7262],
#         [99.9480]], requires_grad=True)
# Step 57, theta:
#  tensor([[-1.7210],
#         [99.9480]], requires_grad=True)
# Step 58, theta:
#  tensor([[-1.7157],
#         [99.9481]], requires_grad=True)
# Step 59, theta:
#  tensor([[-1.7105],
#         [99.9482]], requires_grad=True)
# Step 60, theta:
#  tensor([[-1.7053],
#         [99.9482]], requires_grad=True)
# Step 61, theta:
#  tensor([[-1.7001],
#         [99.9483]], requires_grad=True)
# Step 62, theta:
#  tensor([[-1.6950],
#         [99.9484]], requires_grad=True)
# Step 63, theta:
#  tensor([[-1.6898],
#         [99.9484]], requires_grad=True)
# Step 64, theta:
#  tensor([[-1.6846],
#         [99.9485]], requires_grad=True)
# Step 65, theta:
#  tensor([[-1.6795],
#         [99.9486]], requires_grad=True)
# Step 66, theta:
#  tensor([[-1.6743],
#         [99.9486]], requires_grad=True)
# Step 67, theta:
#  tensor([[-1.6692],
#         [99.9487]], requires_grad=True)
# Step 68, theta:
#  tensor([[-1.6641],
#         [99.9488]], requires_grad=True)
# Step 69, theta:
#  tensor([[-1.6590],
#         [99.9489]], requires_grad=True)
# Step 70, theta:
#  tensor([[-1.6539],
#         [99.9489]], requires_grad=True)
# Step 71, theta:
#  tensor([[-1.6488],
#         [99.9490]], requires_grad=True)
# Step 72, theta:
#  tensor([[-1.6437],
#         [99.9491]], requires_grad=True)
# Step 73, theta:
#  tensor([[-1.6386],
#         [99.9491]], requires_grad=True)
# Step 74, theta:
#  tensor([[-1.6336],
#         [99.9492]], requires_grad=True)
# Step 75, theta:
#  tensor([[-1.6285],
#         [99.9493]], requires_grad=True)
# Step 76, theta:
#  tensor([[-1.6235],
#         [99.9493]], requires_grad=True)
# Step 77, theta:
#  tensor([[-1.6184],
#         [99.9494]], requires_grad=True)
# Step 78, theta:
#  tensor([[-1.6134],
#         [99.9495]], requires_grad=True)
# Step 79, theta:
#  tensor([[-1.6084],
#         [99.9495]], requires_grad=True)
# Step 80, theta:
#  tensor([[-1.6034],
#         [99.9496]], requires_grad=True)
# Step 81, theta:
#  tensor([[-1.5984],
#         [99.9497]], requires_grad=True)
# Step 82, theta:
#  tensor([[-1.5934],
#         [99.9497]], requires_grad=True)
# Step 83, theta:
#  tensor([[-1.5885],
#         [99.9498]], requires_grad=True)
# Step 84, theta:
#  tensor([[-1.5835],
#         [99.9499]], requires_grad=True)
# Step 85, theta:
#  tensor([[-1.5785],
#         [99.9500]], requires_grad=True)
# Step 86, theta:
#  tensor([[-1.5736],
#         [99.9500]], requires_grad=True)
# Step 87, theta:
#  tensor([[-1.5687],
#         [99.9501]], requires_grad=True)
# Step 88, theta:
#  tensor([[-1.5637],
#         [99.9502]], requires_grad=True)
# Step 89, theta:
#  tensor([[-1.5588],
#         [99.9502]], requires_grad=True)
# Step 90, theta:
#  tensor([[-1.5539],
#         [99.9503]], requires_grad=True)
# Step 91, theta:
#  tensor([[-1.5490],
#         [99.9504]], requires_grad=True)
# Step 92, theta:
#  tensor([[-1.5441],
#         [99.9504]], requires_grad=True)
# Step 93, theta:
#  tensor([[-1.5393],
#         [99.9505]], requires_grad=True)
# Step 94, theta:
#  tensor([[-1.5344],
#         [99.9505]], requires_grad=True)
# Step 95, theta:
#  tensor([[-1.5295],
#         [99.9506]], requires_grad=True)
# Step 96, theta:
#  tensor([[-1.5247],
#         [99.9507]], requires_grad=True)
# Step 97, theta:
#  tensor([[-1.5199],
#         [99.9507]], requires_grad=True)
# Step 98, theta:
#  tensor([[-1.5150],
#         [99.9508]], requires_grad=True)
# Step 99, theta:
#  tensor([[-1.5102],
#         [99.9509]], requires_grad=True)
# Step 100, theta:
#  tensor([[-1.5054],
#         [99.9509]], requires_grad=True)
# Step 101, theta:
#  tensor([[-1.5006],
#         [99.9510]], requires_grad=True)
# Step 102, theta:
#  tensor([[-1.4958],
#         [99.9511]], requires_grad=True)
# Step 103, theta:
#  tensor([[-1.4910],
#         [99.9511]], requires_grad=True)
# Step 104, theta:
#  tensor([[-1.4863],
#         [99.9512]], requires_grad=True)
# Step 105, theta:
#  tensor([[-1.4815],
#         [99.9513]], requires_grad=True)
# Step 106, theta:
#  tensor([[-1.4767],
#         [99.9513]], requires_grad=True)
# Step 107, theta:
#  tensor([[-1.4720],
#         [99.9514]], requires_grad=True)
# Step 108, theta:
#  tensor([[-1.4673],
#         [99.9515]], requires_grad=True)
# Step 109, theta:
#  tensor([[-1.4625],
#         [99.9515]], requires_grad=True)
# Step 110, theta:
#  tensor([[-1.4578],
#         [99.9516]], requires_grad=True)
# Step 111, theta:
#  tensor([[-1.4531],
#         [99.9516]], requires_grad=True)
# Step 112, theta:
#  tensor([[-1.4484],
#         [99.9517]], requires_grad=True)
# Step 113, theta:
#  tensor([[-1.4437],
#         [99.9518]], requires_grad=True)
# Step 114, theta:
#  tensor([[-1.4390],
#         [99.9518]], requires_grad=True)
# Step 115, theta:
#  tensor([[-1.4344],
#         [99.9519]], requires_grad=True)
# Step 116, theta:
#  tensor([[-1.4297],
#         [99.9520]], requires_grad=True)
# Step 117, theta:
#  tensor([[-1.4251],
#         [99.9520]], requires_grad=True)
# Step 118, theta:
#  tensor([[-1.4204],
#         [99.9521]], requires_grad=True)
# Step 119, theta:
#  tensor([[-1.4158],
#         [99.9521]], requires_grad=True)
# Step 120, theta:
#  tensor([[-1.4111],
#         [99.9522]], requires_grad=True)
# Step 121, theta:
#  tensor([[-1.4065],
#         [99.9523]], requires_grad=True)
# Step 122, theta:
#  tensor([[-1.4019],
#         [99.9523]], requires_grad=True)
# Step 123, theta:
#  tensor([[-1.3973],
#         [99.9524]], requires_grad=True)
# Step 124, theta:
#  tensor([[-1.3927],
#         [99.9525]], requires_grad=True)
# Step 125, theta:
#  tensor([[-1.3882],
#         [99.9525]], requires_grad=True)
# Step 126, theta:
#  tensor([[-1.3836],
#         [99.9526]], requires_grad=True)
# Step 127, theta:
#  tensor([[-1.3790],
#         [99.9526]], requires_grad=True)
# Step 128, theta:
#  tensor([[-1.3745],
#         [99.9527]], requires_grad=True)
# Step 129, theta:
#  tensor([[-1.3699],
#         [99.9528]], requires_grad=True)
# Step 130, theta:
#  tensor([[-1.3654],
#         [99.9528]], requires_grad=True)
# Step 131, theta:
#  tensor([[-1.3609],
#         [99.9529]], requires_grad=True)
# Step 132, theta:
#  tensor([[-1.3563],
#         [99.9529]], requires_grad=True)
# Step 133, theta:
#  tensor([[-1.3518],
#         [99.9530]], requires_grad=True)
# Step 134, theta:
#  tensor([[-1.3473],
#         [99.9531]], requires_grad=True)
# Step 135, theta:
#  tensor([[-1.3428],
#         [99.9531]], requires_grad=True)
# Step 136, theta:
#  tensor([[-1.3384],
#         [99.9532]], requires_grad=True)
# Step 137, theta:
#  tensor([[-1.3339],
#         [99.9532]], requires_grad=True)
# Step 138, theta:
#  tensor([[-1.3294],
#         [99.9533]], requires_grad=True)
# Step 139, theta:
#  tensor([[-1.3250],
#         [99.9534]], requires_grad=True)
# Step 140, theta:
#  tensor([[-1.3205],
#         [99.9534]], requires_grad=True)
# Step 141, theta:
#  tensor([[-1.3161],
#         [99.9535]], requires_grad=True)
# Step 142, theta:
#  tensor([[-1.3116],
#         [99.9536]], requires_grad=True)
# Step 143, theta:
#  tensor([[-1.3072],
#         [99.9536]], requires_grad=True)
# Step 144, theta:
#  tensor([[-1.3028],
#         [99.9537]], requires_grad=True)
# Step 145, theta:
#  tensor([[-1.2984],
#         [99.9537]], requires_grad=True)
# Step 146, theta:
#  tensor([[-1.2940],
#         [99.9538]], requires_grad=True)
# Step 147, theta:
#  tensor([[-1.2896],
#         [99.9539]], requires_grad=True)
# Step 148, theta:
#  tensor([[-1.2852],
#         [99.9539]], requires_grad=True)
# Step 149, theta:
#  tensor([[-1.2809],
#         [99.9540]], requires_grad=True)
# Step 150, theta:
#  tensor([[-1.2765],
#         [99.9540]], requires_grad=True)
# Step 151, theta:
#  tensor([[-1.2722],
#         [99.9541]], requires_grad=True)
# Step 152, theta:
#  tensor([[-1.2678],
#         [99.9542]], requires_grad=True)
# Step 153, theta:
#  tensor([[-1.2635],
#         [99.9542]], requires_grad=True)
# Step 154, theta:
#  tensor([[-1.2591],
#         [99.9543]], requires_grad=True)
# Step 155, theta:
#  tensor([[-1.2548],
#         [99.9543]], requires_grad=True)
# Step 156, theta:
#  tensor([[-1.2505],
#         [99.9544]], requires_grad=True)
# Step 157, theta:
#  tensor([[-1.2462],
#         [99.9544]], requires_grad=True)
# Step 158, theta:
#  tensor([[-1.2419],
#         [99.9545]], requires_grad=True)
# Step 159, theta:
#  tensor([[-1.2376],
#         [99.9546]], requires_grad=True)
# Step 160, theta:
#  tensor([[-1.2334],
#         [99.9546]], requires_grad=True)
# Step 161, theta:
#  tensor([[-1.2291],
#         [99.9547]], requires_grad=True)
# Step 162, theta:
#  tensor([[-1.2248],
#         [99.9547]], requires_grad=True)
# Step 163, theta:
#  tensor([[-1.2206],
#         [99.9548]], requires_grad=True)
# Step 164, theta:
#  tensor([[-1.2163],
#         [99.9548]], requires_grad=True)
# Step 165, theta:
#  tensor([[-1.2121],
#         [99.9549]], requires_grad=True)
# Step 166, theta:
#  tensor([[-1.2079],
#         [99.9550]], requires_grad=True)
# Step 167, theta:
#  tensor([[-1.2037],
#         [99.9550]], requires_grad=True)
# Step 168, theta:
#  tensor([[-1.1994],
#         [99.9551]], requires_grad=True)
# Step 169, theta:
#  tensor([[-1.1952],
#         [99.9551]], requires_grad=True)
# Step 170, theta:
#  tensor([[-1.1910],
#         [99.9552]], requires_grad=True)
# Step 171, theta:
#  tensor([[-1.1869],
#         [99.9552]], requires_grad=True)
# Step 172, theta:
#  tensor([[-1.1827],
#         [99.9553]], requires_grad=True)
# Step 173, theta:
#  tensor([[-1.1785],
#         [99.9554]], requires_grad=True)
# Step 174, theta:
#  tensor([[-1.1743],
#         [99.9554]], requires_grad=True)
# Step 175, theta:
#  tensor([[-1.1702],
#         [99.9555]], requires_grad=True)
# Step 176, theta:
#  tensor([[-1.1660],
#         [99.9555]], requires_grad=True)
# Step 177, theta:
#  tensor([[-1.1619],
#         [99.9556]], requires_grad=True)
# Step 178, theta:
#  tensor([[-1.1578],
#         [99.9556]], requires_grad=True)
# Step 179, theta:
#  tensor([[-1.1537],
#         [99.9557]], requires_grad=True)
# Step 180, theta:
#  tensor([[-1.1495],
#         [99.9557]], requires_grad=True)
# Step 181, theta:
#  tensor([[-1.1454],
#         [99.9558]], requires_grad=True)
# Step 182, theta:
#  tensor([[-1.1413],
#         [99.9558]], requires_grad=True)
# Step 183, theta:
#  tensor([[-1.1373],
#         [99.9559]], requires_grad=True)
# Step 184, theta:
#  tensor([[-1.1332],
#         [99.9560]], requires_grad=True)
# Step 185, theta:
#  tensor([[-1.1291],
#         [99.9560]], requires_grad=True)
# Step 186, theta:
#  tensor([[-1.1250],
#         [99.9561]], requires_grad=True)
# Step 187, theta:
#  tensor([[-1.1210],
#         [99.9561]], requires_grad=True)
# Step 188, theta:
#  tensor([[-1.1169],
#         [99.9562]], requires_grad=True)
# Step 189, theta:
#  tensor([[-1.1129],
#         [99.9562]], requires_grad=True)
# Step 190, theta:
#  tensor([[-1.1089],
#         [99.9563]], requires_grad=True)
# Step 191, theta:
#  tensor([[-1.1048],
#         [99.9563]], requires_grad=True)
# Step 192, theta:
#  tensor([[-1.1008],
#         [99.9564]], requires_grad=True)
# Step 193, theta:
#  tensor([[-1.0968],
#         [99.9565]], requires_grad=True)
# Step 194, theta:
#  tensor([[-1.0928],
#         [99.9565]], requires_grad=True)
# Step 195, theta:
#  tensor([[-1.0888],
#         [99.9566]], requires_grad=True)
# Step 196, theta:
#  tensor([[-1.0848],
#         [99.9566]], requires_grad=True)
# Step 197, theta:
#  tensor([[-1.0808],
#         [99.9567]], requires_grad=True)
# Step 198, theta:
#  tensor([[-1.0769],
#         [99.9567]], requires_grad=True)
# Step 199, theta:
#  tensor([[-1.0729],
#         [99.9568]], requires_grad=True)
# Step 200, theta:
#  tensor([[-1.0690],
#         [99.9568]], requires_grad=True)
# Step 201, theta:
#  tensor([[-1.0650],
#         [99.9569]], requires_grad=True)
# Step 202, theta:
#  tensor([[-1.0611],
#         [99.9569]], requires_grad=True)
# Step 203, theta:
#  tensor([[-1.0571],
#         [99.9570]], requires_grad=True)
# Step 204, theta:
#  tensor([[-1.0532],
#         [99.9570]], requires_grad=True)
# Step 205, theta:
#  tensor([[-1.0493],
#         [99.9571]], requires_grad=True)
# Step 206, theta:
#  tensor([[-1.0454],
#         [99.9571]], requires_grad=True)
# Step 207, theta:
#  tensor([[-1.0415],
#         [99.9572]], requires_grad=True)
# Step 208, theta:
#  tensor([[-1.0376],
#         [99.9573]], requires_grad=True)
# Step 209, theta:
#  tensor([[-1.0337],
#         [99.9573]], requires_grad=True)
# Step 210, theta:
#  tensor([[-1.0298],
#         [99.9574]], requires_grad=True)
# Step 211, theta:
#  tensor([[-1.0260],
#         [99.9574]], requires_grad=True)
# Step 212, theta:
#  tensor([[-1.0221],
#         [99.9575]], requires_grad=True)
# Step 213, theta:
#  tensor([[-1.0182],
#         [99.9575]], requires_grad=True)
# Step 214, theta:
#  tensor([[-1.0144],
#         [99.9576]], requires_grad=True)
# Step 215, theta:
#  tensor([[-1.0105],
#         [99.9576]], requires_grad=True)
# Step 216, theta:
#  tensor([[-1.0067],
#         [99.9577]], requires_grad=True)
# Step 217, theta:
#  tensor([[-1.0029],
#         [99.9577]], requires_grad=True)
# Step 218, theta:
#  tensor([[-0.9991],
#         [99.9578]], requires_grad=True)
# Step 219, theta:
#  tensor([[-0.9953],
#         [99.9578]], requires_grad=True)
# Step 220, theta:
#  tensor([[-0.9915],
#         [99.9579]], requires_grad=True)
# Step 221, theta:
#  tensor([[-0.9877],
#         [99.9579]], requires_grad=True)
# Step 222, theta:
#  tensor([[-0.9839],
#         [99.9580]], requires_grad=True)
# Step 223, theta:
#  tensor([[-0.9801],
#         [99.9580]], requires_grad=True)
# Step 224, theta:
#  tensor([[-0.9763],
#         [99.9581]], requires_grad=True)
# Step 225, theta:
#  tensor([[-0.9725],
#         [99.9581]], requires_grad=True)
# Step 226, theta:
#  tensor([[-0.9688],
#         [99.9582]], requires_grad=True)
# Step 227, theta:
#  tensor([[-0.9650],
#         [99.9582]], requires_grad=True)
# Step 228, theta:
#  tensor([[-0.9613],
#         [99.9583]], requires_grad=True)
# Step 229, theta:
#  tensor([[-0.9576],
#         [99.9583]], requires_grad=True)
# Step 230, theta:
#  tensor([[-0.9538],
#         [99.9584]], requires_grad=True)
# Step 231, theta:
#  tensor([[-0.9501],
#         [99.9584]], requires_grad=True)
# Step 232, theta:
#  tensor([[-0.9464],
#         [99.9585]], requires_grad=True)
# Step 233, theta:
#  tensor([[-0.9427],
#         [99.9585]], requires_grad=True)
# Step 234, theta:
#  tensor([[-0.9390],
#         [99.9586]], requires_grad=True)
# Step 235, theta:
#  tensor([[-0.9353],
#         [99.9586]], requires_grad=True)
# Step 236, theta:
#  tensor([[-0.9316],
#         [99.9587]], requires_grad=True)
# Step 237, theta:
#  tensor([[-0.9279],
#         [99.9587]], requires_grad=True)
# Step 238, theta:
#  tensor([[-0.9242],
#         [99.9588]], requires_grad=True)
# Step 239, theta:
#  tensor([[-0.9206],
#         [99.9588]], requires_grad=True)
# Step 240, theta:
#  tensor([[-0.9169],
#         [99.9589]], requires_grad=True)
# Step 241, theta:
#  tensor([[-0.9133],
#         [99.9589]], requires_grad=True)
# Step 242, theta:
#  tensor([[-0.9096],
#         [99.9590]], requires_grad=True)
# Step 243, theta:
#  tensor([[-0.9060],
#         [99.9590]], requires_grad=True)
# Step 244, theta:
#  tensor([[-0.9024],
#         [99.9591]], requires_grad=True)
# Step 245, theta:
#  tensor([[-0.8987],
#         [99.9591]], requires_grad=True)
# Step 246, theta:
#  tensor([[-0.8951],
#         [99.9592]], requires_grad=True)
# Step 247, theta:
#  tensor([[-0.8915],
#         [99.9592]], requires_grad=True)
# Step 248, theta:
#  tensor([[-0.8879],
#         [99.9593]], requires_grad=True)
# Step 249, theta:
#  tensor([[-0.8843],
#         [99.9593]], requires_grad=True)
# Step 250, theta:
#  tensor([[-0.8807],
#         [99.9594]], requires_grad=True)
# Step 251, theta:
#  tensor([[-0.8772],
#         [99.9594]], requires_grad=True)
# Step 252, theta:
#  tensor([[-0.8736],
#         [99.9595]], requires_grad=True)
# Step 253, theta:
#  tensor([[-0.8700],
#         [99.9595]], requires_grad=True)
# Step 254, theta:
#  tensor([[-0.8665],
#         [99.9596]], requires_grad=True)
# Step 255, theta:
#  tensor([[-0.8629],
#         [99.9596]], requires_grad=True)
# Step 256, theta:
#  tensor([[-0.8594],
#         [99.9597]], requires_grad=True)
# Step 257, theta:
#  tensor([[-0.8558],
#         [99.9597]], requires_grad=True)
# Step 258, theta:
#  tensor([[-0.8523],
#         [99.9598]], requires_grad=True)
# Step 259, theta:
#  tensor([[-0.8488],
#         [99.9598]], requires_grad=True)
# Step 260, theta:
#  tensor([[-0.8453],
#         [99.9599]], requires_grad=True)
# Step 261, theta:
#  tensor([[-0.8417],
#         [99.9599]], requires_grad=True)
# Step 262, theta:
#  tensor([[-0.8382],
#         [99.9599]], requires_grad=True)
# Step 263, theta:
#  tensor([[-0.8347],
#         [99.9600]], requires_grad=True)
# Step 264, theta:
#  tensor([[-0.8313],
#         [99.9600]], requires_grad=True)
# Step 265, theta:
#  tensor([[-0.8278],
#         [99.9601]], requires_grad=True)
# Step 266, theta:
#  tensor([[-0.8243],
#         [99.9601]], requires_grad=True)
# Step 267, theta:
#  tensor([[-0.8208],
#         [99.9602]], requires_grad=True)
# Step 268, theta:
#  tensor([[-0.8174],
#         [99.9602]], requires_grad=True)
# Step 269, theta:
#  tensor([[-0.8139],
#         [99.9603]], requires_grad=True)
# Step 270, theta:
#  tensor([[-0.8105],
#         [99.9603]], requires_grad=True)
# Step 271, theta:
#  tensor([[-0.8070],
#         [99.9604]], requires_grad=True)
# Step 272, theta:
#  tensor([[-0.8036],
#         [99.9604]], requires_grad=True)
# Step 273, theta:
#  tensor([[-0.8002],
#         [99.9605]], requires_grad=True)
# Step 274, theta:
#  tensor([[-0.7967],
#         [99.9605]], requires_grad=True)
# Step 275, theta:
#  tensor([[-0.7933],
#         [99.9605]], requires_grad=True)
# Step 276, theta:
#  tensor([[-0.7899],
#         [99.9606]], requires_grad=True)
# Step 277, theta:
#  tensor([[-0.7865],
#         [99.9606]], requires_grad=True)
# Step 278, theta:
#  tensor([[-0.7831],
#         [99.9607]], requires_grad=True)
# Step 279, theta:
#  tensor([[-0.7797],
#         [99.9607]], requires_grad=True)
# Step 280, theta:
#  tensor([[-0.7763],
#         [99.9608]], requires_grad=True)
# Step 281, theta:
#  tensor([[-0.7730],
#         [99.9608]], requires_grad=True)
# Step 282, theta:
#  tensor([[-0.7696],
#         [99.9609]], requires_grad=True)
# Step 283, theta:
#  tensor([[-0.7662],
#         [99.9609]], requires_grad=True)
# Step 284, theta:
#  tensor([[-0.7629],
#         [99.9610]], requires_grad=True)
# Step 285, theta:
#  tensor([[-0.7595],
#         [99.9610]], requires_grad=True)
# Step 286, theta:
#  tensor([[-0.7562],
#         [99.9611]], requires_grad=True)
# Step 287, theta:
#  tensor([[-0.7528],
#         [99.9611]], requires_grad=True)
# Step 288, theta:
#  tensor([[-0.7495],
#         [99.9611]], requires_grad=True)
# Step 289, theta:
#  tensor([[-0.7462],
#         [99.9612]], requires_grad=True)
# Step 290, theta:
#  tensor([[-0.7429],
#         [99.9612]], requires_grad=True)
# Step 291, theta:
#  tensor([[-0.7396],
#         [99.9613]], requires_grad=True)
# Step 292, theta:
#  tensor([[-0.7363],
#         [99.9613]], requires_grad=True)
# Step 293, theta:
#  tensor([[-0.7330],
#         [99.9614]], requires_grad=True)
# Step 294, theta:
#  tensor([[-0.7297],
#         [99.9614]], requires_grad=True)
# Step 295, theta:
#  tensor([[-0.7264],
#         [99.9615]], requires_grad=True)
# Step 296, theta:
#  tensor([[-0.7231],
#         [99.9615]], requires_grad=True)
# Step 297, theta:
#  tensor([[-0.7198],
#         [99.9616]], requires_grad=True)
# Step 298, theta:
#  tensor([[-0.7166],
#         [99.9616]], requires_grad=True)
# Step 299, theta:
#  tensor([[-0.7133],
#         [99.9616]], requires_grad=True)
# Step 300, theta:
#  tensor([[-0.7101],
#         [99.9617]], requires_grad=True)
# Step 301, theta:
#  tensor([[-0.7068],
#         [99.9617]], requires_grad=True)
# Step 302, theta:
#  tensor([[-0.7036],
#         [99.9618]], requires_grad=True)
# Step 303, theta:
#  tensor([[-0.7003],
#         [99.9618]], requires_grad=True)
# Step 304, theta:
#  tensor([[-0.6971],
#         [99.9619]], requires_grad=True)
# Step 305, theta:
#  tensor([[-0.6939],
#         [99.9619]], requires_grad=True)
# Step 306, theta:
#  tensor([[-0.6907],
#         [99.9620]], requires_grad=True)
# Step 307, theta:
#  tensor([[-0.6875],
#         [99.9620]], requires_grad=True)
# Step 308, theta:
#  tensor([[-0.6843],
#         [99.9620]], requires_grad=True)
# Step 309, theta:
#  tensor([[-0.6811],
#         [99.9621]], requires_grad=True)
# Step 310, theta:
#  tensor([[-0.6779],
#         [99.9621]], requires_grad=True)
# Step 311, theta:
#  tensor([[-0.6747],
#         [99.9622]], requires_grad=True)
# Step 312, theta:
#  tensor([[-0.6715],
#         [99.9622]], requires_grad=True)
# Step 313, theta:
#  tensor([[-0.6684],
#         [99.9622]], requires_grad=True)
# Step 314, theta:
#  tensor([[-0.6652],
#         [99.9623]], requires_grad=True)
# Step 315, theta:
#  tensor([[-0.6620],
#         [99.9623]], requires_grad=True)
# Step 316, theta:
#  tensor([[-0.6589],
#         [99.9624]], requires_grad=True)
# Step 317, theta:
#  tensor([[-0.6557],
#         [99.9624]], requires_grad=True)
# Step 318, theta:
#  tensor([[-0.6526],
#         [99.9625]], requires_grad=True)
# Step 319, theta:
#  tensor([[-0.6495],
#         [99.9625]], requires_grad=True)
# Step 320, theta:
#  tensor([[-0.6463],
#         [99.9625]], requires_grad=True)
# Step 321, theta:
#  tensor([[-0.6432],
#         [99.9626]], requires_grad=True)
# Step 322, theta:
#  tensor([[-0.6401],
#         [99.9626]], requires_grad=True)
# Step 323, theta:
#  tensor([[-0.6370],
#         [99.9627]], requires_grad=True)
# Step 324, theta:
#  tensor([[-0.6339],
#         [99.9627]], requires_grad=True)
# Step 325, theta:
#  tensor([[-0.6308],
#         [99.9628]], requires_grad=True)
# Step 326, theta:
#  tensor([[-0.6277],
#         [99.9628]], requires_grad=True)
# Step 327, theta:
#  tensor([[-0.6246],
#         [99.9628]], requires_grad=True)
# Step 328, theta:
#  tensor([[-0.6215],
#         [99.9629]], requires_grad=True)
# Step 329, theta:
#  tensor([[-0.6185],
#         [99.9629]], requires_grad=True)
# Step 330, theta:
#  tensor([[-0.6154],
#         [99.9630]], requires_grad=True)
# Step 331, theta:
#  tensor([[-0.6123],
#         [99.9630]], requires_grad=True)
# Step 332, theta:
#  tensor([[-0.6093],
#         [99.9630]], requires_grad=True)
# Step 333, theta:
#  tensor([[-0.6062],
#         [99.9631]], requires_grad=True)
# Step 334, theta:
#  tensor([[-0.6032],
#         [99.9631]], requires_grad=True)
# Step 335, theta:
#  tensor([[-0.6001],
#         [99.9632]], requires_grad=True)
# Step 336, theta:
#  tensor([[-0.5971],
#         [99.9632]], requires_grad=True)
# Step 337, theta:
#  tensor([[-0.5941],
#         [99.9632]], requires_grad=True)
# Step 338, theta:
#  tensor([[-0.5911],
#         [99.9633]], requires_grad=True)
# Step 339, theta:
#  tensor([[-0.5881],
#         [99.9633]], requires_grad=True)
# Step 340, theta:
#  tensor([[-0.5851],
#         [99.9634]], requires_grad=True)
# Step 341, theta:
#  tensor([[-0.5821],
#         [99.9634]], requires_grad=True)
# Step 342, theta:
#  tensor([[-0.5791],
#         [99.9634]], requires_grad=True)
# Step 343, theta:
#  tensor([[-0.5761],
#         [99.9635]], requires_grad=True)
# Step 344, theta:
#  tensor([[-0.5731],
#         [99.9635]], requires_grad=True)
# Step 345, theta:
#  tensor([[-0.5701],
#         [99.9636]], requires_grad=True)
# Step 346, theta:
#  tensor([[-0.5671],
#         [99.9636]], requires_grad=True)
# Step 347, theta:
#  tensor([[-0.5642],
#         [99.9637]], requires_grad=True)
# Step 348, theta:
#  tensor([[-0.5612],
#         [99.9637]], requires_grad=True)
# Step 349, theta:
#  tensor([[-0.5582],
#         [99.9637]], requires_grad=True)
# Step 350, theta:
#  tensor([[-0.5553],
#         [99.9638]], requires_grad=True)
# Step 351, theta:
#  tensor([[-0.5524],
#         [99.9638]], requires_grad=True)
# Step 352, theta:
#  tensor([[-0.5494],
#         [99.9638]], requires_grad=True)
# Step 353, theta:
#  tensor([[-0.5465],
#         [99.9639]], requires_grad=True)
# Step 354, theta:
#  tensor([[-0.5436],
#         [99.9639]], requires_grad=True)
# Step 355, theta:
#  tensor([[-0.5406],
#         [99.9640]], requires_grad=True)
# Step 356, theta:
#  tensor([[-0.5377],
#         [99.9640]], requires_grad=True)
# Step 357, theta:
#  tensor([[-0.5348],
#         [99.9640]], requires_grad=True)
# Step 358, theta:
#  tensor([[-0.5319],
#         [99.9641]], requires_grad=True)
# Step 359, theta:
#  tensor([[-0.5290],
#         [99.9641]], requires_grad=True)
# Step 360, theta:
#  tensor([[-0.5261],
#         [99.9642]], requires_grad=True)
# Step 361, theta:
#  tensor([[-0.5232],
#         [99.9642]], requires_grad=True)
# Step 362, theta:
#  tensor([[-0.5204],
#         [99.9642]], requires_grad=True)
# Step 363, theta:
#  tensor([[-0.5175],
#         [99.9643]], requires_grad=True)
# Step 364, theta:
#  tensor([[-0.5146],
#         [99.9643]], requires_grad=True)
# Step 365, theta:
#  tensor([[-0.5117],
#         [99.9644]], requires_grad=True)
# Step 366, theta:
#  tensor([[-0.5089],
#         [99.9644]], requires_grad=True)
# Step 367, theta:
#  tensor([[-0.5060],
#         [99.9644]], requires_grad=True)
# Step 368, theta:
#  tensor([[-0.5032],
#         [99.9645]], requires_grad=True)
# Step 369, theta:
#  tensor([[-0.5003],
#         [99.9645]], requires_grad=True)
# Step 370, theta:
#  tensor([[-0.4975],
#         [99.9645]], requires_grad=True)
# Step 371, theta:
#  tensor([[-0.4947],
#         [99.9646]], requires_grad=True)
# Step 372, theta:
#  tensor([[-0.4919],
#         [99.9646]], requires_grad=True)
# Step 373, theta:
#  tensor([[-0.4890],
#         [99.9647]], requires_grad=True)
# Step 374, theta:
#  tensor([[-0.4862],
#         [99.9647]], requires_grad=True)
# Step 375, theta:
#  tensor([[-0.4834],
#         [99.9647]], requires_grad=True)
# Step 376, theta:
#  tensor([[-0.4806],
#         [99.9648]], requires_grad=True)
# Step 377, theta:
#  tensor([[-0.4778],
#         [99.9648]], requires_grad=True)
# Step 378, theta:
#  tensor([[-0.4750],
#         [99.9649]], requires_grad=True)
# Step 379, theta:
#  tensor([[-0.4722],
#         [99.9649]], requires_grad=True)
# Step 380, theta:
#  tensor([[-0.4694],
#         [99.9649]], requires_grad=True)
# Step 381, theta:
#  tensor([[-0.4667],
#         [99.9650]], requires_grad=True)
# Step 382, theta:
#  tensor([[-0.4639],
#         [99.9650]], requires_grad=True)
# Step 383, theta:
#  tensor([[-0.4611],
#         [99.9650]], requires_grad=True)
# Step 384, theta:
#  tensor([[-0.4584],
#         [99.9651]], requires_grad=True)
# Step 385, theta:
#  tensor([[-0.4556],
#         [99.9651]], requires_grad=True)
# Step 386, theta:
#  tensor([[-0.4529],
#         [99.9652]], requires_grad=True)
# Step 387, theta:
#  tensor([[-0.4501],
#         [99.9652]], requires_grad=True)
# Step 388, theta:
#  tensor([[-0.4474],
#         [99.9652]], requires_grad=True)
# Step 389, theta:
#  tensor([[-0.4447],
#         [99.9653]], requires_grad=True)
# Step 390, theta:
#  tensor([[-0.4419],
#         [99.9653]], requires_grad=True)
# Step 391, theta:
#  tensor([[-0.4392],
#         [99.9653]], requires_grad=True)
# Step 392, theta:
#  tensor([[-0.4365],
#         [99.9654]], requires_grad=True)
# Step 393, theta:
#  tensor([[-0.4338],
#         [99.9654]], requires_grad=True)
# Step 394, theta:
#  tensor([[-0.4311],
#         [99.9655]], requires_grad=True)
# Step 395, theta:
#  tensor([[-0.4284],
#         [99.9655]], requires_grad=True)
# Step 396, theta:
#  tensor([[-0.4257],
#         [99.9655]], requires_grad=True)
# Step 397, theta:
#  tensor([[-0.4230],
#         [99.9656]], requires_grad=True)
# Step 398, theta:
#  tensor([[-0.4203],
#         [99.9656]], requires_grad=True)
# Step 399, theta:
#  tensor([[-0.4176],
#         [99.9656]], requires_grad=True)
# Step 400, theta:
#  tensor([[-0.4150],
#         [99.9657]], requires_grad=True)
# Step 401, theta:
#  tensor([[-0.4123],
#         [99.9657]], requires_grad=True)
# Step 402, theta:
#  tensor([[-0.4096],
#         [99.9658]], requires_grad=True)
# Step 403, theta:
#  tensor([[-0.4070],
#         [99.9658]], requires_grad=True)
# Step 404, theta:
#  tensor([[-0.4043],
#         [99.9658]], requires_grad=True)
# Step 405, theta:
#  tensor([[-0.4017],
#         [99.9659]], requires_grad=True)
# Step 406, theta:
#  tensor([[-0.3990],
#         [99.9659]], requires_grad=True)
# Step 407, theta:
#  tensor([[-0.3964],
#         [99.9659]], requires_grad=True)
# Step 408, theta:
#  tensor([[-0.3937],
#         [99.9660]], requires_grad=True)
# Step 409, theta:
#  tensor([[-0.3911],
#         [99.9660]], requires_grad=True)
# Step 410, theta:
#  tensor([[-0.3885],
#         [99.9660]], requires_grad=True)
# Step 411, theta:
#  tensor([[-0.3859],
#         [99.9661]], requires_grad=True)
# Step 412, theta:
#  tensor([[-0.3833],
#         [99.9661]], requires_grad=True)
# Step 413, theta:
#  tensor([[-0.3807],
#         [99.9661]], requires_grad=True)
# Step 414, theta:
#  tensor([[-0.3781],
#         [99.9662]], requires_grad=True)
# Step 415, theta:
#  tensor([[-0.3755],
#         [99.9662]], requires_grad=True)
# Step 416, theta:
#  tensor([[-0.3729],
#         [99.9662]], requires_grad=True)
# Step 417, theta:
#  tensor([[-0.3703],
#         [99.9663]], requires_grad=True)
# Step 418, theta:
#  tensor([[-0.3677],
#         [99.9663]], requires_grad=True)
# Step 419, theta:
#  tensor([[-0.3651],
#         [99.9663]], requires_grad=True)
# Step 420, theta:
#  tensor([[-0.3625],
#         [99.9664]], requires_grad=True)
# Step 421, theta:
#  tensor([[-0.3600],
#         [99.9664]], requires_grad=True)
# Step 422, theta:
#  tensor([[-0.3574],
#         [99.9665]], requires_grad=True)
# Step 423, theta:
#  tensor([[-0.3549],
#         [99.9665]], requires_grad=True)
# Step 424, theta:
#  tensor([[-0.3523],
#         [99.9665]], requires_grad=True)
# Step 425, theta:
#  tensor([[-0.3498],
#         [99.9666]], requires_grad=True)
# Step 426, theta:
#  tensor([[-0.3472],
#         [99.9666]], requires_grad=True)
# Step 427, theta:
#  tensor([[-0.3447],
#         [99.9666]], requires_grad=True)
# Step 428, theta:
#  tensor([[-0.3422],
#         [99.9667]], requires_grad=True)
# Step 429, theta:
#  tensor([[-0.3396],
#         [99.9667]], requires_grad=True)
# Step 430, theta:
#  tensor([[-0.3371],
#         [99.9667]], requires_grad=True)
# Step 431, theta:
#  tensor([[-0.3346],
#         [99.9668]], requires_grad=True)
# Step 432, theta:
#  tensor([[-0.3321],
#         [99.9668]], requires_grad=True)
# Step 433, theta:
#  tensor([[-0.3296],
#         [99.9668]], requires_grad=True)
# Step 434, theta:
#  tensor([[-0.3271],
#         [99.9669]], requires_grad=True)
# Step 435, theta:
#  tensor([[-0.3246],
#         [99.9669]], requires_grad=True)
# Step 436, theta:
#  tensor([[-0.3221],
#         [99.9669]], requires_grad=True)
# Step 437, theta:
#  tensor([[-0.3196],
#         [99.9670]], requires_grad=True)
# Step 438, theta:
#  tensor([[-0.3171],
#         [99.9670]], requires_grad=True)
# Step 439, theta:
#  tensor([[-0.3146],
#         [99.9670]], requires_grad=True)
# Step 440, theta:
#  tensor([[-0.3122],
#         [99.9671]], requires_grad=True)
# Step 441, theta:
#  tensor([[-0.3097],
#         [99.9671]], requires_grad=True)
# Step 442, theta:
#  tensor([[-0.3072],
#         [99.9671]], requires_grad=True)
# Step 443, theta:
#  tensor([[-0.3048],
#         [99.9672]], requires_grad=True)
# Step 444, theta:
#  tensor([[-0.3023],
#         [99.9672]], requires_grad=True)
# Step 445, theta:
#  tensor([[-0.2999],
#         [99.9672]], requires_grad=True)
# Step 446, theta:
#  tensor([[-0.2974],
#         [99.9673]], requires_grad=True)
# Step 447, theta:
#  tensor([[-0.2950],
#         [99.9673]], requires_grad=True)
# Step 448, theta:
#  tensor([[-0.2925],
#         [99.9673]], requires_grad=True)
# Step 449, theta:
#  tensor([[-0.2901],
#         [99.9674]], requires_grad=True)
# Step 450, theta:
#  tensor([[-0.2877],
#         [99.9674]], requires_grad=True)
# Step 451, theta:
#  tensor([[-0.2853],
#         [99.9674]], requires_grad=True)
# Step 452, theta:
#  tensor([[-0.2828],
#         [99.9675]], requires_grad=True)
# Step 453, theta:
#  tensor([[-0.2804],
#         [99.9675]], requires_grad=True)
# Step 454, theta:
#  tensor([[-0.2780],
#         [99.9675]], requires_grad=True)
# Step 455, theta:
#  tensor([[-0.2756],
#         [99.9675]], requires_grad=True)
# Step 456, theta:
#  tensor([[-0.2732],
#         [99.9676]], requires_grad=True)
# Step 457, theta:
#  tensor([[-0.2708],
#         [99.9676]], requires_grad=True)
# Step 458, theta:
#  tensor([[-0.2685],
#         [99.9676]], requires_grad=True)
# Step 459, theta:
#  tensor([[-0.2661],
#         [99.9677]], requires_grad=True)
# Step 460, theta:
#  tensor([[-0.2637],
#         [99.9677]], requires_grad=True)
# Step 461, theta:
#  tensor([[-0.2613],
#         [99.9677]], requires_grad=True)
# Step 462, theta:
#  tensor([[-0.2590],
#         [99.9678]], requires_grad=True)
# Step 463, theta:
#  tensor([[-0.2566],
#         [99.9678]], requires_grad=True)
# Step 464, theta:
#  tensor([[-0.2542],
#         [99.9678]], requires_grad=True)
# Step 465, theta:
#  tensor([[-0.2519],
#         [99.9679]], requires_grad=True)
# Step 466, theta:
#  tensor([[-0.2495],
#         [99.9679]], requires_grad=True)
# Step 467, theta:
#  tensor([[-0.2472],
#         [99.9679]], requires_grad=True)
# Step 468, theta:
#  tensor([[-0.2448],
#         [99.9680]], requires_grad=True)
# Step 469, theta:
#  tensor([[-0.2425],
#         [99.9680]], requires_grad=True)
# Step 470, theta:
#  tensor([[-0.2402],
#         [99.9680]], requires_grad=True)
# Step 471, theta:
#  tensor([[-0.2378],
#         [99.9681]], requires_grad=True)
# Step 472, theta:
#  tensor([[-0.2355],
#         [99.9681]], requires_grad=True)
# Step 473, theta:
#  tensor([[-0.2332],
#         [99.9681]], requires_grad=True)
# Step 474, theta:
#  tensor([[-0.2309],
#         [99.9681]], requires_grad=True)
# Step 475, theta:
#  tensor([[-0.2286],
#         [99.9682]], requires_grad=True)
# Step 476, theta:
#  tensor([[-0.2263],
#         [99.9682]], requires_grad=True)
# Step 477, theta:
#  tensor([[-0.2240],
#         [99.9682]], requires_grad=True)
# Step 478, theta:
#  tensor([[-0.2217],
#         [99.9683]], requires_grad=True)
# Step 479, theta:
#  tensor([[-0.2194],
#         [99.9683]], requires_grad=True)
# Step 480, theta:
#  tensor([[-0.2171],
#         [99.9683]], requires_grad=True)
# Step 481, theta:
#  tensor([[-0.2148],
#         [99.9684]], requires_grad=True)
# Step 482, theta:
#  tensor([[-0.2125],
#         [99.9684]], requires_grad=True)
# Step 483, theta:
#  tensor([[-0.2103],
#         [99.9684]], requires_grad=True)
# Step 484, theta:
#  tensor([[-0.2080],
#         [99.9685]], requires_grad=True)
# Step 485, theta:
#  tensor([[-0.2057],
#         [99.9685]], requires_grad=True)
# Step 486, theta:
#  tensor([[-0.2035],
#         [99.9685]], requires_grad=True)
# Step 487, theta:
#  tensor([[-0.2012],
#         [99.9686]], requires_grad=True)
# Step 488, theta:
#  tensor([[-0.1990],
#         [99.9686]], requires_grad=True)
# Step 489, theta:
#  tensor([[-0.1967],
#         [99.9686]], requires_grad=True)
# Step 490, theta:
#  tensor([[-0.1945],
#         [99.9686]], requires_grad=True)
# Step 491, theta:
#  tensor([[-0.1922],
#         [99.9687]], requires_grad=True)
# Step 492, theta:
#  tensor([[-0.1900],
#         [99.9687]], requires_grad=True)
# Step 493, theta:
#  tensor([[-0.1878],
#         [99.9687]], requires_grad=True)
# Step 494, theta:
#  tensor([[-0.1855],
#         [99.9688]], requires_grad=True)
# Step 495, theta:
#  tensor([[-0.1833],
#         [99.9688]], requires_grad=True)
# Step 496, theta:
#  tensor([[-0.1811],
#         [99.9688]], requires_grad=True)
# Step 497, theta:
#  tensor([[-0.1789],
#         [99.9689]], requires_grad=True)
# Step 498, theta:
#  tensor([[-0.1767],
#         [99.9689]], requires_grad=True)
# Step 499, theta:
#  tensor([[-0.1745],
#         [99.9689]], requires_grad=True)
# Step 500, theta:
#  tensor([[-0.1723],
#         [99.9689]], requires_grad=True)
# Step 501, theta:
#  tensor([[-0.1701],
#         [99.9690]], requires_grad=True)
# Step 502, theta:
#  tensor([[-0.1679],
#         [99.9690]], requires_grad=True)
# Step 503, theta:
#  tensor([[-0.1657],
#         [99.9690]], requires_grad=True)
# Step 504, theta:
#  tensor([[-0.1635],
#         [99.9691]], requires_grad=True)
# Step 505, theta:
#  tensor([[-0.1613],
#         [99.9691]], requires_grad=True)
# Step 506, theta:
#  tensor([[-0.1592],
#         [99.9691]], requires_grad=True)
# Step 507, theta:
#  tensor([[-0.1570],
#         [99.9692]], requires_grad=True)
# Step 508, theta:
#  tensor([[-0.1548],
#         [99.9692]], requires_grad=True)
# Step 509, theta:
#  tensor([[-0.1527],
#         [99.9692]], requires_grad=True)
# Step 510, theta:
#  tensor([[-0.1505],
#         [99.9693]], requires_grad=True)
# Step 511, theta:
#  tensor([[-0.1484],
#         [99.9693]], requires_grad=True)
# Step 512, theta:
#  tensor([[-0.1462],
#         [99.9693]], requires_grad=True)
# Step 513, theta:
#  tensor([[-0.1441],
#         [99.9693]], requires_grad=True)
# Step 514, theta:
#  tensor([[-0.1419],
#         [99.9694]], requires_grad=True)
# Step 515, theta:
#  tensor([[-0.1398],
#         [99.9694]], requires_grad=True)
# Step 516, theta:
#  tensor([[-0.1377],
#         [99.9694]], requires_grad=True)
# Step 517, theta:
#  tensor([[-0.1355],
#         [99.9695]], requires_grad=True)
# Step 518, theta:
#  tensor([[-0.1334],
#         [99.9695]], requires_grad=True)
# Step 519, theta:
#  tensor([[-0.1313],
#         [99.9695]], requires_grad=True)
# Step 520, theta:
#  tensor([[-0.1292],
#         [99.9695]], requires_grad=True)
# Step 521, theta:
#  tensor([[-0.1271],
#         [99.9696]], requires_grad=True)
# Step 522, theta:
#  tensor([[-0.1250],
#         [99.9696]], requires_grad=True)
# Step 523, theta:
#  tensor([[-0.1229],
#         [99.9696]], requires_grad=True)
# Step 524, theta:
#  tensor([[-0.1208],
#         [99.9697]], requires_grad=True)
# Step 525, theta:
#  tensor([[-0.1187],
#         [99.9697]], requires_grad=True)
# Step 526, theta:
#  tensor([[-0.1166],
#         [99.9697]], requires_grad=True)
# Step 527, theta:
#  tensor([[-0.1145],
#         [99.9697]], requires_grad=True)
# Step 528, theta:
#  tensor([[-0.1124],
#         [99.9698]], requires_grad=True)
# Step 529, theta:
#  tensor([[-0.1103],
#         [99.9698]], requires_grad=True)
# Step 530, theta:
#  tensor([[-0.1083],
#         [99.9698]], requires_grad=True)
# Step 531, theta:
#  tensor([[-0.1062],
#         [99.9698]], requires_grad=True)
# Step 532, theta:
#  tensor([[-0.1041],
#         [99.9699]], requires_grad=True)
# Step 533, theta:
#  tensor([[-0.1021],
#         [99.9699]], requires_grad=True)
# Step 534, theta:
#  tensor([[-0.1000],
#         [99.9699]], requires_grad=True)
# Step 535, theta:
#  tensor([[-9.7956e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 536, theta:
#  tensor([[-9.5906e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 537, theta:
#  tensor([[-9.3860e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 538, theta:
#  tensor([[-9.1819e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 539, theta:
#  tensor([[-8.9781e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 540, theta:
#  tensor([[-8.7747e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 541, theta:
#  tensor([[-8.5717e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 542, theta:
#  tensor([[-8.3692e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 543, theta:
#  tensor([[-8.1670e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 544, theta:
#  tensor([[-7.9652e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 545, theta:
#  tensor([[-7.7638e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 546, theta:
#  tensor([[-7.5628e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 547, theta:
#  tensor([[-7.3622e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 548, theta:
#  tensor([[-7.1620e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 549, theta:
#  tensor([[-6.9622e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 550, theta:
#  tensor([[-6.7628e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 551, theta:
#  tensor([[-6.5637e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 552, theta:
#  tensor([[-6.3651e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 553, theta:
#  tensor([[-6.1668e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 554, theta:
#  tensor([[-5.9689e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 555, theta:
#  tensor([[-5.7715e-02],
#         [ 9.9970e+01]], requires_grad=True)
# Step 556, theta:
#  tensor([[-5.5744e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 557, theta:
#  tensor([[-5.3776e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 558, theta:
#  tensor([[-5.1813e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 559, theta:
#  tensor([[-4.9854e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 560, theta:
#  tensor([[-4.7898e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 561, theta:
#  tensor([[-4.5946e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 562, theta:
#  tensor([[-4.3998e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 563, theta:
#  tensor([[-4.2054e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 564, theta:
#  tensor([[-4.0114e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 565, theta:
#  tensor([[-3.8177e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 566, theta:
#  tensor([[-3.6244e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 567, theta:
#  tensor([[-3.4315e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 568, theta:
#  tensor([[-3.2390e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 569, theta:
#  tensor([[-3.0468e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 570, theta:
#  tensor([[-2.8551e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 571, theta:
#  tensor([[-2.6637e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 572, theta:
#  tensor([[-2.4726e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 573, theta:
#  tensor([[-2.2820e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 574, theta:
#  tensor([[-2.0917e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 575, theta:
#  tensor([[-1.9018e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 576, theta:
#  tensor([[-1.7122e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 577, theta:
#  tensor([[-1.5231e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 578, theta:
#  tensor([[-1.3343e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 579, theta:
#  tensor([[-1.1459e-02],
#         [ 9.9971e+01]], requires_grad=True)
# Step 580, theta:
#  tensor([[-9.5780e-03],
#         [ 9.9971e+01]], requires_grad=True)
# Step 581, theta:
#  tensor([[-7.7011e-03],
#         [ 9.9971e+01]], requires_grad=True)
# Step 582, theta:
#  tensor([[-5.8278e-03],
#         [ 9.9971e+01]], requires_grad=True)
# Step 583, theta:
#  tensor([[-3.9583e-03],
#         [ 9.9971e+01]], requires_grad=True)
# Step 584, theta:
#  tensor([[-2.0923e-03],
#         [ 9.9971e+01]], requires_grad=True)
# Step 585, theta:
#  tensor([[-2.3006e-04],
#         [ 9.9971e+01]], requires_grad=True)
# Step 586, theta:
#  tensor([[1.6286e-03],
#         [9.9971e+01]], requires_grad=True)
# Step 587, theta:
#  tensor([[3.4836e-03],
#         [9.9971e+01]], requires_grad=True)
# Step 588, theta:
#  tensor([[5.3349e-03],
#         [9.9971e+01]], requires_grad=True)
# Step 589, theta:
#  tensor([[7.1827e-03],
#         [9.9971e+01]], requires_grad=True)
# Step 590, theta:
#  tensor([[9.0268e-03],
#         [9.9971e+01]], requires_grad=True)
# Step 591, theta:
#  tensor([[1.0867e-02],
#         [9.9971e+01]], requires_grad=True)
# Step 592, theta:
#  tensor([[1.2704e-02],
#         [9.9971e+01]], requires_grad=True)
# Step 593, theta:
#  tensor([[1.4538e-02],
#         [9.9971e+01]], requires_grad=True)
# Step 594, theta:
#  tensor([[1.6367e-02],
#         [9.9971e+01]], requires_grad=True)
# Step 595, theta:
#  tensor([[1.8194e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 596, theta:
#  tensor([[2.0016e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 597, theta:
#  tensor([[2.1835e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 598, theta:
#  tensor([[2.3651e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 599, theta:
#  tensor([[2.5463e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 600, theta:
#  tensor([[2.7271e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 601, theta:
#  tensor([[2.9076e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 602, theta:
#  tensor([[3.0877e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 603, theta:
#  tensor([[3.2675e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 604, theta:
#  tensor([[3.4470e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 605, theta:
#  tensor([[3.6260e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 606, theta:
#  tensor([[3.8048e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 607, theta:
#  tensor([[3.9831e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 608, theta:
#  tensor([[4.1612e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 609, theta:
#  tensor([[4.3389e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 610, theta:
#  tensor([[4.5162e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 611, theta:
#  tensor([[4.6932e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 612, theta:
#  tensor([[4.8698e-02],
#         [9.9972e+01]], requires_grad=True)
# Step 613, theta:
#  tensor([[5.0461e-02],
#         [9.9972e+01]], requires_grad=True)
# ...
#         [99.9748]], requires_grad=True)
# Step 748, theta:
#  tensor([[ 0.2594],
#         [99.9748]], requires_grad=True)
# Step 749, theta:
#  tensor([[ 0.2608],
#         [99.9748]], requires_grad=True)
# Step 750, theta:
#  tensor([[ 0.2621],
#         [99.9748]], requires_grad=True)
# Step 751, theta:
#  tensor([[ 0.2635],
#         [99.9748]], requires_grad=True)
# Step 752, theta:
#  tensor([[ 0.2648],
#         [99.9749]], requires_grad=True)
# Step 753, theta:
#  tensor([[ 0.2662],
#         [99.9749]], requires_grad=True)
# Step 754, theta:
#  tensor([[ 0.2675],
#         [99.9749]], requires_grad=True)
# Step 755, theta:
#  tensor([[ 0.2688],
#         [99.9749]], requires_grad=True)
# Step 756, theta:
#  tensor([[ 0.2702],
#         [99.9749]], requires_grad=True)
# Step 757, theta:
#  tensor([[ 0.2715],
#         [99.9749]], requires_grad=True)
# Step 758, theta:
#  tensor([[ 0.2728],
#         [99.9750]], requires_grad=True)
# Step 759, theta:
#  tensor([[ 0.2741],
#         [99.9750]], requires_grad=True)
# Step 760, theta:
#  tensor([[ 0.2755],
#         [99.9750]], requires_grad=True)
# Step 761, theta:
#  tensor([[ 0.2768],
#         [99.9750]], requires_grad=True)
# Step 762, theta:
#  tensor([[ 0.2781],
#         [99.9750]], requires_grad=True)
# Step 763, theta:
#  tensor([[ 0.2794],
#         [99.9751]], requires_grad=True)
# Step 764, theta:
#  tensor([[ 0.2807],
#         [99.9751]], requires_grad=True)
# Step 765, theta:
#  tensor([[ 0.2820],
#         [99.9751]], requires_grad=True)
# Step 766, theta:
#  tensor([[ 0.2833],
#         [99.9751]], requires_grad=True)
# Step 767, theta:
#  tensor([[ 0.2847],
#         [99.9751]], requires_grad=True)
# Step 768, theta:
#  tensor([[ 0.2860],
#         [99.9751]], requires_grad=True)
# Step 769, theta:
#  tensor([[ 0.2873],
#         [99.9752]], requires_grad=True)
# Step 770, theta:
#  tensor([[ 0.2885],
#         [99.9752]], requires_grad=True)
# Step 771, theta:
#  tensor([[ 0.2898],
#         [99.9752]], requires_grad=True)
# Step 772, theta:
#  tensor([[ 0.2911],
#         [99.9752]], requires_grad=True)
# Step 773, theta:
#  tensor([[ 0.2924],
#         [99.9752]], requires_grad=True)
# Step 774, theta:
#  tensor([[ 0.2937],
#         [99.9752]], requires_grad=True)
# Step 775, theta:
#  tensor([[ 0.2950],
#         [99.9753]], requires_grad=True)
# Step 776, theta:
#  tensor([[ 0.2963],
#         [99.9753]], requires_grad=True)
# Step 777, theta:
#  tensor([[ 0.2976],
#         [99.9753]], requires_grad=True)
# Step 778, theta:
#  tensor([[ 0.2988],
#         [99.9753]], requires_grad=True)
# Step 779, theta:
#  tensor([[ 0.3001],
#         [99.9753]], requires_grad=True)
# Step 780, theta:
#  tensor([[ 0.3014],
#         [99.9753]], requires_grad=True)
# Step 781, theta:
#  tensor([[ 0.3026],
#         [99.9754]], requires_grad=True)
# Step 782, theta:
#  tensor([[ 0.3039],
#         [99.9754]], requires_grad=True)
# Step 783, theta:
#  tensor([[ 0.3052],
#         [99.9754]], requires_grad=True)
# Step 784, theta:
#  tensor([[ 0.3064],
#         [99.9754]], requires_grad=True)
# Step 785, theta:
#  tensor([[ 0.3077],
#         [99.9754]], requires_grad=True)
# Step 786, theta:
#  tensor([[ 0.3090],
#         [99.9754]], requires_grad=True)
# Step 787, theta:
#  tensor([[ 0.3102],
#         [99.9755]], requires_grad=True)
# Step 788, theta:
#  tensor([[ 0.3115],
#         [99.9755]], requires_grad=True)
# Step 789, theta:
#  tensor([[ 0.3127],
#         [99.9755]], requires_grad=True)
# Step 790, theta:
#  tensor([[ 0.3140],
#         [99.9755]], requires_grad=True)
# Step 791, theta:
#  tensor([[ 0.3152],
#         [99.9755]], requires_grad=True)
# Step 792, theta:
#  tensor([[ 0.3164],
#         [99.9755]], requires_grad=True)
# Step 793, theta:
#  tensor([[ 0.3177],
#         [99.9756]], requires_grad=True)
# Step 794, theta:
#  tensor([[ 0.3189],
#         [99.9756]], requires_grad=True)
# Step 795, theta:
#  tensor([[ 0.3202],
#         [99.9756]], requires_grad=True)
# Step 796, theta:
#  tensor([[ 0.3214],
#         [99.9756]], requires_grad=True)
# Step 797, theta:
#  tensor([[ 0.3226],
#         [99.9756]], requires_grad=True)
# Step 798, theta:
#  tensor([[ 0.3238],
#         [99.9756]], requires_grad=True)
# Step 799, theta:
#  tensor([[ 0.3251],
#         [99.9757]], requires_grad=True)
# Step 800, theta:
#  tensor([[ 0.3263],
#         [99.9757]], requires_grad=True)
# Step 801, theta:
#  tensor([[ 0.3275],
#         [99.9757]], requires_grad=True)
# Step 802, theta:
#  tensor([[ 0.3287],
#         [99.9757]], requires_grad=True)
# Step 803, theta:
#  tensor([[ 0.3299],
#         [99.9757]], requires_grad=True)
# Step 804, theta:
#  tensor([[ 0.3312],
#         [99.9757]], requires_grad=True)
# Step 805, theta:
#  tensor([[ 0.3324],
#         [99.9758]], requires_grad=True)
# Step 806, theta:
#  tensor([[ 0.3336],
#         [99.9758]], requires_grad=True)
# Step 807, theta:
#  tensor([[ 0.3348],
#         [99.9758]], requires_grad=True)
# Step 808, theta:
#  tensor([[ 0.3360],
#         [99.9758]], requires_grad=True)
# Step 809, theta:
#  tensor([[ 0.3372],
#         [99.9758]], requires_grad=True)
# Step 810, theta:
#  tensor([[ 0.3384],
#         [99.9758]], requires_grad=True)
# Step 811, theta:
#  tensor([[ 0.3396],
#         [99.9759]], requires_grad=True)
# Step 812, theta:
#  tensor([[ 0.3408],
#         [99.9759]], requires_grad=True)
# Step 813, theta:
#  tensor([[ 0.3420],
#         [99.9759]], requires_grad=True)
# Step 814, theta:
#  tensor([[ 0.3432],
#         [99.9759]], requires_grad=True)
# Step 815, theta:
#  tensor([[ 0.3444],
#         [99.9759]], requires_grad=True)
# Step 816, theta:
#  tensor([[ 0.3455],
#         [99.9759]], requires_grad=True)
# Step 817, theta:
#  tensor([[ 0.3467],
#         [99.9760]], requires_grad=True)
# Step 818, theta:
#  tensor([[ 0.3479],
#         [99.9760]], requires_grad=True)
# Step 819, theta:
#  tensor([[ 0.3491],
#         [99.9760]], requires_grad=True)
# Step 820, theta:
#  tensor([[ 0.3503],
#         [99.9760]], requires_grad=True)
# Step 821, theta:
#  tensor([[ 0.3514],
#         [99.9760]], requires_grad=True)
# Step 822, theta:
#  tensor([[ 0.3526],
#         [99.9760]], requires_grad=True)
# Step 823, theta:
#  tensor([[ 0.3538],
#         [99.9761]], requires_grad=True)
# Step 824, theta:
#  tensor([[ 0.3549],
#         [99.9761]], requires_grad=True)
# Step 825, theta:
#  tensor([[ 0.3561],
#         [99.9761]], requires_grad=True)
# Step 826, theta:
#  tensor([[ 0.3573],
#         [99.9761]], requires_grad=True)
# Step 827, theta:
#  tensor([[ 0.3584],
#         [99.9761]], requires_grad=True)
# Step 828, theta:
#  tensor([[ 0.3596],
#         [99.9761]], requires_grad=True)
# Step 829, theta:
#  tensor([[ 0.3607],
#         [99.9761]], requires_grad=True)
# Step 830, theta:
#  tensor([[ 0.3619],
#         [99.9762]], requires_grad=True)
# Step 831, theta:
#  tensor([[ 0.3630],
#         [99.9762]], requires_grad=True)
# Step 832, theta:
#  tensor([[ 0.3642],
#         [99.9762]], requires_grad=True)
# Step 833, theta:
#  tensor([[ 0.3653],
#         [99.9762]], requires_grad=True)
# Step 834, theta:
#  tensor([[ 0.3665],
#         [99.9762]], requires_grad=True)
# Step 835, theta:
#  tensor([[ 0.3676],
#         [99.9762]], requires_grad=True)
# Step 836, theta:
#  tensor([[ 0.3688],
#         [99.9762]], requires_grad=True)
# Step 837, theta:
#  tensor([[ 0.3699],
#         [99.9763]], requires_grad=True)
# Step 838, theta:
#  tensor([[ 0.3710],
#         [99.9763]], requires_grad=True)
# Step 839, theta:
#  tensor([[ 0.3722],
#         [99.9763]], requires_grad=True)
# Step 840, theta:
#  tensor([[ 0.3733],
#         [99.9763]], requires_grad=True)
# Step 841, theta:
#  tensor([[ 0.3744],
#         [99.9763]], requires_grad=True)
# Step 842, theta:
#  tensor([[ 0.3755],
#         [99.9763]], requires_grad=True)
# Step 843, theta:
#  tensor([[ 0.3767],
#         [99.9764]], requires_grad=True)
# Step 844, theta:
#  tensor([[ 0.3778],
#         [99.9764]], requires_grad=True)
# Step 845, theta:
#  tensor([[ 0.3789],
#         [99.9764]], requires_grad=True)
# Step 846, theta:
#  tensor([[ 0.3800],
#         [99.9764]], requires_grad=True)
# Step 847, theta:
#  tensor([[ 0.3811],
#         [99.9764]], requires_grad=True)
# Step 848, theta:
#  tensor([[ 0.3823],
#         [99.9764]], requires_grad=True)
# Step 849, theta:
#  tensor([[ 0.3834],
#         [99.9764]], requires_grad=True)
# Step 850, theta:
#  tensor([[ 0.3845],
#         [99.9765]], requires_grad=True)
# Step 851, theta:
#  tensor([[ 0.3856],
#         [99.9765]], requires_grad=True)
# Step 852, theta:
#  tensor([[ 0.3867],
#         [99.9765]], requires_grad=True)
# Step 853, theta:
#  tensor([[ 0.3878],
#         [99.9765]], requires_grad=True)
# Step 854, theta:
#  tensor([[ 0.3889],
#         [99.9765]], requires_grad=True)
# Step 855, theta:
#  tensor([[ 0.3900],
#         [99.9765]], requires_grad=True)
# Step 856, theta:
#  tensor([[ 0.3911],
#         [99.9766]], requires_grad=True)
# Step 857, theta:
#  tensor([[ 0.3922],
#         [99.9766]], requires_grad=True)
# Step 858, theta:
#  tensor([[ 0.3933],
#         [99.9766]], requires_grad=True)
# Step 859, theta:
#  tensor([[ 0.3944],
#         [99.9766]], requires_grad=True)
# Step 860, theta:
#  tensor([[ 0.3955],
#         [99.9766]], requires_grad=True)
# Step 861, theta:
#  tensor([[ 0.3965],
#         [99.9766]], requires_grad=True)
# Step 862, theta:
#  tensor([[ 0.3976],
#         [99.9766]], requires_grad=True)
# Step 863, theta:
#  tensor([[ 0.3987],
#         [99.9767]], requires_grad=True)
# Step 864, theta:
#  tensor([[ 0.3998],
#         [99.9767]], requires_grad=True)
# Step 865, theta:
#  tensor([[ 0.4009],
#         [99.9767]], requires_grad=True)
# Step 866, theta:
#  tensor([[ 0.4019],
#         [99.9767]], requires_grad=True)
# Step 867, theta:
#  tensor([[ 0.4030],
#         [99.9767]], requires_grad=True)
# Step 868, theta:
#  tensor([[ 0.4041],
#         [99.9767]], requires_grad=True)
# Step 869, theta:
#  tensor([[ 0.4051],
#         [99.9768]], requires_grad=True)
# Step 870, theta:
#  tensor([[ 0.4062],
#         [99.9768]], requires_grad=True)
# Step 871, theta:
#  tensor([[ 0.4073],
#         [99.9768]], requires_grad=True)
# Step 872, theta:
#  tensor([[ 0.4083],
#         [99.9768]], requires_grad=True)
# Step 873, theta:
#  tensor([[ 0.4094],
#         [99.9768]], requires_grad=True)
# Step 874, theta:
#  tensor([[ 0.4105],
#         [99.9768]], requires_grad=True)
# Step 875, theta:
#  tensor([[ 0.4115],
#         [99.9768]], requires_grad=True)
# Step 876, theta:
#  tensor([[ 0.4126],
#         [99.9769]], requires_grad=True)
# Step 877, theta:
#  tensor([[ 0.4136],
#         [99.9769]], requires_grad=True)
# Step 878, theta:
#  tensor([[ 0.4147],
#         [99.9769]], requires_grad=True)
# Step 879, theta:
#  tensor([[ 0.4157],
#         [99.9769]], requires_grad=True)
# Step 880, theta:
#  tensor([[ 0.4168],
#         [99.9769]], requires_grad=True)
# Step 881, theta:
#  tensor([[ 0.4178],
#         [99.9769]], requires_grad=True)
# Step 882, theta:
#  tensor([[ 0.4188],
#         [99.9769]], requires_grad=True)
# Step 883, theta:
#  tensor([[ 0.4199],
#         [99.9770]], requires_grad=True)
# Step 884, theta:
#  tensor([[ 0.4209],
#         [99.9770]], requires_grad=True)
# Step 885, theta:
#  tensor([[ 0.4220],
#         [99.9770]], requires_grad=True)
# Step 886, theta:
#  tensor([[ 0.4230],
#         [99.9770]], requires_grad=True)
# Step 887, theta:
#  tensor([[ 0.4240],
#         [99.9770]], requires_grad=True)
# Step 888, theta:
#  tensor([[ 0.4251],
#         [99.9770]], requires_grad=True)
# Step 889, theta:
#  tensor([[ 0.4261],
#         [99.9770]], requires_grad=True)
# Step 890, theta:
#  tensor([[ 0.4271],
#         [99.9771]], requires_grad=True)
# Step 891, theta:
#  tensor([[ 0.4281],
#         [99.9771]], requires_grad=True)
# Step 892, theta:
#  tensor([[ 0.4291],
#         [99.9771]], requires_grad=True)
# Step 893, theta:
#  tensor([[ 0.4302],
#         [99.9771]], requires_grad=True)
# Step 894, theta:
#  tensor([[ 0.4312],
#         [99.9771]], requires_grad=True)
# Step 895, theta:
#  tensor([[ 0.4322],
#         [99.9771]], requires_grad=True)
# Step 896, theta:
#  tensor([[ 0.4332],
#         [99.9771]], requires_grad=True)
# Step 897, theta:
#  tensor([[ 0.4342],
#         [99.9771]], requires_grad=True)
# Step 898, theta:
#  tensor([[ 0.4352],
#         [99.9772]], requires_grad=True)
# Step 899, theta:
#  tensor([[ 0.4362],
#         [99.9772]], requires_grad=True)
# Step 900, theta:
#  tensor([[ 0.4372],
#         [99.9772]], requires_grad=True)
# Step 901, theta:
#  tensor([[ 0.4383],
#         [99.9772]], requires_grad=True)
# Step 902, theta:
#  tensor([[ 0.4393],
#         [99.9772]], requires_grad=True)
# 903
# [1274792.375, 750923.75, 414844.25, 227089.5, 124146.5859375, 67857.78125, 37091.4609375, 20276.169921875, 11085.8779296875, 6062.96630859375, 3317.72412109375, 1817.3157958984375, 997.2669677734375, 549.0563354492188, 304.0777282714844, 170.1721954345703, 96.97246551513672, 56.95161056518555, 35.06401824951172, 23.087337493896484, 16.52690887451172, 12.927186965942383, 10.945646286010742, 9.848628997802734, 9.235031127929688, 8.885645866394043, 8.680723190307617, 8.554919242858887, 8.472285270690918, 8.41342544555664, 8.367461204528809, 8.328756332397461, 8.293901443481445, 8.261381149291992, 8.230055809020996, 8.199522972106934, 8.169397354125977, 8.139652252197266, 8.110016822814941, 8.0806245803833, 8.051301956176758, 8.022150039672852, 7.993208408355713, 7.96426248550415, 7.935504913330078, 7.906838893890381, 7.878289222717285, 7.849886894226074, 7.821482181549072, 7.793282508850098, 7.765210151672363, 7.737185478210449, 7.709249973297119, 7.681507110595703, 7.653845310211182, 7.626262664794922, 7.598848819732666, 7.571478366851807, 7.54422664642334, 7.517108917236328, 7.490059852600098, 7.463213920593262, 7.436300754547119, 7.409609317779541, 7.383000373840332, 7.356462001800537, 7.330088138580322, 7.303765773773193, 7.277606964111328, 7.251486301422119, 7.225518226623535, 7.1996331214904785, 7.173806667327881, 7.148118019104004, 7.122536659240723, 7.097079277038574, 7.071684837341309, 7.046422481536865, 7.021175384521484, 6.996069431304932, 6.9711127281188965, 6.946209907531738, 6.921402931213379, 6.8966875076293945, 6.872087001800537, 6.847564697265625, 6.82314920425415, 6.798880100250244, 6.77462100982666, 6.750425815582275, 6.726449489593506, 6.702491760253906, 6.678694248199463, 6.654879570007324, 6.6312456130981445, 6.60763692855835, 6.5841875076293945, 6.560821533203125, 6.53756856918335, 6.514293670654297, 6.491189002990723, 6.468170166015625, 6.445237636566162, 6.422393798828125, 6.399626731872559, 6.376971244812012, 6.354376792907715, 6.331918239593506, 6.30948543548584, 6.287181854248047, 6.26496696472168, 6.2428975105285645, 6.220761775970459, 6.1988019943237305, 6.176939487457275, 6.155123233795166, 6.133423805236816, 6.111788749694824, 6.090241432189941, 6.068759441375732, 6.047401428222656, 6.026134967803955, 6.0049052238464355, 5.98382043838501, 5.9627485275268555, 5.941788673400879, 5.920928001403809, 5.90009880065918, 5.879417896270752, 5.858763694763184, 5.838229179382324, 5.81776237487793, 5.797356128692627, 5.77701473236084, 5.756795406341553, 5.736612796783447, 5.716558933258057, 5.696552753448486, 5.676690101623535, 5.65682315826416, 5.637017250061035, 5.617337226867676, 5.59774112701416, 5.578214168548584, 5.558745861053467, 5.539340019226074, 5.520086288452148, 5.500826835632324, 5.481675624847412, 5.462600231170654, 5.4435930252075195, 5.4246697425842285, 5.405801296234131, 5.387005805969238, 5.368322372436523, 5.349647521972656, 5.331127166748047, 5.312605381011963, 5.294186592102051, 5.275841236114502, 5.25756311416626, 5.239315986633301, 5.221215724945068, 5.203171253204346, 5.185150623321533, 5.1672515869140625, 5.149405479431152, 5.131612300872803, 5.113879203796387, 5.096217632293701, 5.0786895751953125, 5.0611572265625, 5.043731212615967, 5.026369094848633, 5.0090203285217285, 4.991832733154297, 4.9746294021606445, 4.9575324058532715, 4.940510272979736, 4.923540115356445, 4.906668663024902, 4.88983154296875, 4.873044013977051, 4.856332778930664, 4.839663505554199, 4.82311487197876, 4.806618690490723, 4.79019021987915, 4.773768901824951, 4.757464408874512, 4.741227626800537, 4.725035667419434, 4.708883762359619, 4.692852973937988, 4.676859378814697, 4.660874366760254, 4.645010471343994, 4.629242897033691, 4.613468170166016, 4.597760200500488, 4.582158088684082, 4.566606521606445, 4.551060676574707, 4.535611152648926, 4.520203113555908, 4.5049333572387695, 4.489650726318359, 4.474432945251465, 4.459288120269775, 4.444232940673828, 4.429177284240723, 4.414231300354004, 4.399313449859619, 4.3 ...

# %%
np.random.seed(45)
num_samples = 40
    
# Generate data
x1 = np.random.uniform(-1, 1, num_samples)
f_x = 3*x1 + 4
eps = np.random.randn(num_samples)
y = f_x + eps

# %%
theta=torch.randn((2,1),requires_grad=True)

x=torch.tensor(x1,dtype=torch.float32).view(-1, 1)       #reshape is same as view
x=torch.cat((torch.ones(x.shape[0],1),x), dim=1)
y =torch.tensor(y, dtype=torch.float32).view(-1, 1)
theta_hist=[]
loss_hist=[]
learning_rate=0.001
beta = 0.08
v_t = torch.zeros_like(theta)
Epoch=0
while(True):
    Epoch+=1
    theta_old=theta.clone()
    theta_hist.append(theta_old.detach().numpy().flatten())
    y_pred=torch.matmul(x,theta)
    loss=torch.mean((y-y_pred)**2)
    loss_hist.append(loss.clone().detach().item())
    loss.backward()       # As soon as you alled the backward func in the loss it calculates the grad  of loss wrt defined var which has req_grad=True and stores in the defined var.grad
    with torch.no_grad():
        v_t = beta*v_t + (1-beta)*theta.grad
        theta-=learning_rate*v_t
        theta.grad.zero_()
        if(abs(theta_old[0]-theta[0])<0.001 and abs(theta_old[1]-theta[1])<0.001):
            break
    print(f"Step {Epoch}, theta:\n", theta)
print(Epoch) 
print(loss_hist)
# Out:
# Step 1, theta:
#  tensor([[1.2571],
#         [2.2963]], requires_grad=True)
# Step 2, theta:
#  tensor([[1.2623],
#         [2.2961]], requires_grad=True)
# Step 3, theta:
#  tensor([[1.2677],
#         [2.2959]], requires_grad=True)
# Step 4, theta:
#  tensor([[1.2730],
#         [2.2957]], requires_grad=True)
# Step 5, theta:
#  tensor([[1.2782],
#         [2.2955]], requires_grad=True)
# Step 6, theta:
#  tensor([[1.2835],
#         [2.2953]], requires_grad=True)
# Step 7, theta:
#  tensor([[1.2888],
#         [2.2951]], requires_grad=True)
# Step 8, theta:
#  tensor([[1.2941],
#         [2.2949]], requires_grad=True)
# Step 9, theta:
#  tensor([[1.2993],
#         [2.2947]], requires_grad=True)
# Step 10, theta:
#  tensor([[1.3045],
#         [2.2945]], requires_grad=True)
# Step 11, theta:
#  tensor([[1.3098],
#         [2.2943]], requires_grad=True)
# Step 12, theta:
#  tensor([[1.3150],
#         [2.2941]], requires_grad=True)
# Step 13, theta:
#  tensor([[1.3202],
#         [2.2939]], requires_grad=True)
# Step 14, theta:
#  tensor([[1.3254],
#         [2.2937]], requires_grad=True)
# Step 15, theta:
#  tensor([[1.3306],
#         [2.2935]], requires_grad=True)
# Step 16, theta:
#  tensor([[1.3358],
#         [2.2933]], requires_grad=True)
# Step 17, theta:
#  tensor([[1.3409],
#         [2.2931]], requires_grad=True)
# Step 18, theta:
#  tensor([[1.3461],
#         [2.2929]], requires_grad=True)
# Step 19, theta:
#  tensor([[1.3512],
#         [2.2927]], requires_grad=True)
# Step 20, theta:
#  tensor([[1.3563],
#         [2.2925]], requires_grad=True)
# Step 21, theta:
#  tensor([[1.3615],
#         [2.2923]], requires_grad=True)
# Step 22, theta:
#  tensor([[1.3666],
#         [2.2921]], requires_grad=True)
# Step 23, theta:
#  tensor([[1.3717],
#         [2.2919]], requires_grad=True)
# Step 24, theta:
#  tensor([[1.3768],
#         [2.2917]], requires_grad=True)
# Step 25, theta:
#  tensor([[1.3819],
#         [2.2915]], requires_grad=True)
# Step 26, theta:
#  tensor([[1.3869],
#         [2.2913]], requires_grad=True)
# Step 27, theta:
#  tensor([[1.3920],
#         [2.2912]], requires_grad=True)
# Step 28, theta:
#  tensor([[1.3971],
#         [2.2910]], requires_grad=True)
# Step 29, theta:
#  tensor([[1.4021],
#         [2.2908]], requires_grad=True)
# Step 30, theta:
#  tensor([[1.4071],
#         [2.2906]], requires_grad=True)
# Step 31, theta:
#  tensor([[1.4121],
#         [2.2904]], requires_grad=True)
# Step 32, theta:
#  tensor([[1.4172],
#         [2.2902]], requires_grad=True)
# Step 33, theta:
#  tensor([[1.4222],
#         [2.2901]], requires_grad=True)
# Step 34, theta:
#  tensor([[1.4272],
#         [2.2899]], requires_grad=True)
# Step 35, theta:
#  tensor([[1.4321],
#         [2.2897]], requires_grad=True)
# Step 36, theta:
#  tensor([[1.4371],
#         [2.2895]], requires_grad=True)
# Step 37, theta:
#  tensor([[1.4421],
#         [2.2893]], requires_grad=True)
# Step 38, theta:
#  tensor([[1.4470],
#         [2.2892]], requires_grad=True)
# Step 39, theta:
#  tensor([[1.4520],
#         [2.2890]], requires_grad=True)
# Step 40, theta:
#  tensor([[1.4569],
#         [2.2888]], requires_grad=True)
# Step 41, theta:
#  tensor([[1.4618],
#         [2.2886]], requires_grad=True)
# Step 42, theta:
#  tensor([[1.4667],
#         [2.2885]], requires_grad=True)
# Step 43, theta:
#  tensor([[1.4716],
#         [2.2883]], requires_grad=True)
# Step 44, theta:
#  tensor([[1.4765],
#         [2.2881]], requires_grad=True)
# Step 45, theta:
#  tensor([[1.4814],
#         [2.2879]], requires_grad=True)
# Step 46, theta:
#  tensor([[1.4863],
#         [2.2878]], requires_grad=True)
# Step 47, theta:
#  tensor([[1.4911],
#         [2.2876]], requires_grad=True)
# Step 48, theta:
#  tensor([[1.4960],
#         [2.2874]], requires_grad=True)
# Step 49, theta:
#  tensor([[1.5008],
#         [2.2873]], requires_grad=True)
# Step 50, theta:
#  tensor([[1.5057],
#         [2.2871]], requires_grad=True)
# Step 51, theta:
#  tensor([[1.5105],
#         [2.2869]], requires_grad=True)
# Step 52, theta:
#  tensor([[1.5153],
#         [2.2868]], requires_grad=True)
# Step 53, theta:
#  tensor([[1.5201],
#         [2.2866]], requires_grad=True)
# Step 54, theta:
#  tensor([[1.5249],
#         [2.2865]], requires_grad=True)
# Step 55, theta:
#  tensor([[1.5297],
#         [2.2863]], requires_grad=True)
# Step 56, theta:
#  tensor([[1.5345],
#         [2.2861]], requires_grad=True)
# Step 57, theta:
#  tensor([[1.5392],
#         [2.2860]], requires_grad=True)
# Step 58, theta:
#  tensor([[1.5440],
#         [2.2858]], requires_grad=True)
# Step 59, theta:
#  tensor([[1.5487],
#         [2.2857]], requires_grad=True)
# Step 60, theta:
#  tensor([[1.5535],
#         [2.2855]], requires_grad=True)
# Step 61, theta:
#  tensor([[1.5582],
#         [2.2854]], requires_grad=True)
# Step 62, theta:
#  tensor([[1.5629],
#         [2.2852]], requires_grad=True)
# Step 63, theta:
#  tensor([[1.5676],
#         [2.2850]], requires_grad=True)
# Step 64, theta:
#  tensor([[1.5723],
#         [2.2849]], requires_grad=True)
# Step 65, theta:
#  tensor([[1.5770],
#         [2.2847]], requires_grad=True)
# Step 66, theta:
#  tensor([[1.5817],
#         [2.2846]], requires_grad=True)
# Step 67, theta:
#  tensor([[1.5864],
#         [2.2844]], requires_grad=True)
# Step 68, theta:
#  tensor([[1.5910],
#         [2.2843]], requires_grad=True)
# Step 69, theta:
#  tensor([[1.5957],
#         [2.2841]], requires_grad=True)
# Step 70, theta:
#  tensor([[1.6003],
#         [2.2840]], requires_grad=True)
# Step 71, theta:
#  tensor([[1.6050],
#         [2.2838]], requires_grad=True)
# Step 72, theta:
#  tensor([[1.6096],
#         [2.2837]], requires_grad=True)
# Step 73, theta:
#  tensor([[1.6142],
#         [2.2836]], requires_grad=True)
# Step 74, theta:
#  tensor([[1.6188],
#         [2.2834]], requires_grad=True)
# Step 75, theta:
#  tensor([[1.6234],
#         [2.2833]], requires_grad=True)
# Step 76, theta:
#  tensor([[1.6280],
#         [2.2831]], requires_grad=True)
# Step 77, theta:
#  tensor([[1.6326],
#         [2.2830]], requires_grad=True)
# Step 78, theta:
#  tensor([[1.6371],
#         [2.2828]], requires_grad=True)
# Step 79, theta:
#  tensor([[1.6417],
#         [2.2827]], requires_grad=True)
# Step 80, theta:
#  tensor([[1.6463],
#         [2.2826]], requires_grad=True)
# Step 81, theta:
#  tensor([[1.6508],
#         [2.2824]], requires_grad=True)
# Step 82, theta:
#  tensor([[1.6553],
#         [2.2823]], requires_grad=True)
# Step 83, theta:
#  tensor([[1.6599],
#         [2.2822]], requires_grad=True)
# Step 84, theta:
#  tensor([[1.6644],
#         [2.2820]], requires_grad=True)
# Step 85, theta:
#  tensor([[1.6689],
#         [2.2819]], requires_grad=True)
# Step 86, theta:
#  tensor([[1.6734],
#         [2.2818]], requires_grad=True)
# Step 87, theta:
#  tensor([[1.6779],
#         [2.2816]], requires_grad=True)
# Step 88, theta:
#  tensor([[1.6823],
#         [2.2815]], requires_grad=True)
# Step 89, theta:
#  tensor([[1.6868],
#         [2.2814]], requires_grad=True)
# Step 90, theta:
#  tensor([[1.6913],
#         [2.2812]], requires_grad=True)
# Step 91, theta:
#  tensor([[1.6957],
#         [2.2811]], requires_grad=True)
# Step 92, theta:
#  tensor([[1.7002],
#         [2.2810]], requires_grad=True)
# Step 93, theta:
#  tensor([[1.7046],
#         [2.2808]], requires_grad=True)
# Step 94, theta:
#  tensor([[1.7090],
#         [2.2807]], requires_grad=True)
# Step 95, theta:
#  tensor([[1.7134],
#         [2.2806]], requires_grad=True)
# Step 96, theta:
#  tensor([[1.7178],
#         [2.2805]], requires_grad=True)
# Step 97, theta:
#  tensor([[1.7222],
#         [2.2803]], requires_grad=True)
# Step 98, theta:
#  tensor([[1.7266],
#         [2.2802]], requires_grad=True)
# Step 99, theta:
#  tensor([[1.7310],
#         [2.2801]], requires_grad=True)
# Step 100, theta:
#  tensor([[1.7354],
#         [2.2800]], requires_grad=True)
# Step 101, theta:
#  tensor([[1.7397],
#         [2.2799]], requires_grad=True)
# Step 102, theta:
#  tensor([[1.7441],
#         [2.2797]], requires_grad=True)
# Step 103, theta:
#  tensor([[1.7484],
#         [2.2796]], requires_grad=True)
# Step 104, theta:
#  tensor([[1.7528],
#         [2.2795]], requires_grad=True)
# Step 105, theta:
#  tensor([[1.7571],
#         [2.2794]], requires_grad=True)
# Step 106, theta:
#  tensor([[1.7614],
#         [2.2793]], requires_grad=True)
# Step 107, theta:
#  tensor([[1.7657],
#         [2.2791]], requires_grad=True)
# Step 108, theta:
#  tensor([[1.7700],
#         [2.2790]], requires_grad=True)
# Step 109, theta:
#  tensor([[1.7743],
#         [2.2789]], requires_grad=True)
# Step 110, theta:
#  tensor([[1.7786],
#         [2.2788]], requires_grad=True)
# Step 111, theta:
#  tensor([[1.7829],
#         [2.2787]], requires_grad=True)
# Step 112, theta:
#  tensor([[1.7872],
#         [2.2786]], requires_grad=True)
# Step 113, theta:
#  tensor([[1.7914],
#         [2.2785]], requires_grad=True)
# Step 114, theta:
#  tensor([[1.7957],
#         [2.2784]], requires_grad=True)
# Step 115, theta:
#  tensor([[1.7999],
#         [2.2782]], requires_grad=True)
# Step 116, theta:
#  tensor([[1.8042],
#         [2.2781]], requires_grad=True)
# Step 117, theta:
#  tensor([[1.8084],
#         [2.2780]], requires_grad=True)
# Step 118, theta:
#  tensor([[1.8126],
#         [2.2779]], requires_grad=True)
# Step 119, theta:
#  tensor([[1.8168],
#         [2.2778]], requires_grad=True)
# Step 120, theta:
#  tensor([[1.8210],
#         [2.2777]], requires_grad=True)
# Step 121, theta:
#  tensor([[1.8252],
#         [2.2776]], requires_grad=True)
# Step 122, theta:
#  tensor([[1.8294],
#         [2.2775]], requires_grad=True)
# Step 123, theta:
#  tensor([[1.8336],
#         [2.2774]], requires_grad=True)
# Step 124, theta:
#  tensor([[1.8377],
#         [2.2773]], requires_grad=True)
# Step 125, theta:
#  tensor([[1.8419],
#         [2.2772]], requires_grad=True)
# Step 126, theta:
#  tensor([[1.8460],
#         [2.2771]], requires_grad=True)
# Step 127, theta:
#  tensor([[1.8502],
#         [2.2770]], requires_grad=True)
# Step 128, theta:
#  tensor([[1.8543],
#         [2.2769]], requires_grad=True)
# Step 129, theta:
#  tensor([[1.8584],
#         [2.2768]], requires_grad=True)
# Step 130, theta:
#  tensor([[1.8625],
#         [2.2767]], requires_grad=True)
# Step 131, theta:
#  tensor([[1.8667],
#         [2.2766]], requires_grad=True)
# Step 132, theta:
#  tensor([[1.8708],
#         [2.2765]], requires_grad=True)
# Step 133, theta:
#  tensor([[1.8748],
#         [2.2764]], requires_grad=True)
# Step 134, theta:
#  tensor([[1.8789],
#         [2.2763]], requires_grad=True)
# Step 135, theta:
#  tensor([[1.8830],
#         [2.2762]], requires_grad=True)
# Step 136, theta:
#  tensor([[1.8871],
#         [2.2761]], requires_grad=True)
# Step 137, theta:
#  tensor([[1.8911],
#         [2.2760]], requires_grad=True)
# Step 138, theta:
#  tensor([[1.8952],
#         [2.2759]], requires_grad=True)
# Step 139, theta:
#  tensor([[1.8992],
#         [2.2758]], requires_grad=True)
# Step 140, theta:
#  tensor([[1.9033],
#         [2.2757]], requires_grad=True)
# Step 141, theta:
#  tensor([[1.9073],
#         [2.2757]], requires_grad=True)
# Step 142, theta:
#  tensor([[1.9113],
#         [2.2756]], requires_grad=True)
# Step 143, theta:
#  tensor([[1.9153],
#         [2.2755]], requires_grad=True)
# Step 144, theta:
#  tensor([[1.9193],
#         [2.2754]], requires_grad=True)
# Step 145, theta:
#  tensor([[1.9233],
#         [2.2753]], requires_grad=True)
# Step 146, theta:
#  tensor([[1.9273],
#         [2.2752]], requires_grad=True)
# Step 147, theta:
#  tensor([[1.9313],
#         [2.2751]], requires_grad=True)
# Step 148, theta:
#  tensor([[1.9352],
#         [2.2751]], requires_grad=True)
# Step 149, theta:
#  tensor([[1.9392],
#         [2.2750]], requires_grad=True)
# Step 150, theta:
#  tensor([[1.9432],
#         [2.2749]], requires_grad=True)
# Step 151, theta:
#  tensor([[1.9471],
#         [2.2748]], requires_grad=True)
# Step 152, theta:
#  tensor([[1.9511],
#         [2.2747]], requires_grad=True)
# Step 153, theta:
#  tensor([[1.9550],
#         [2.2746]], requires_grad=True)
# Step 154, theta:
#  tensor([[1.9589],
#         [2.2746]], requires_grad=True)
# Step 155, theta:
#  tensor([[1.9628],
#         [2.2745]], requires_grad=True)
# Step 156, theta:
#  tensor([[1.9667],
#         [2.2744]], requires_grad=True)
# Step 157, theta:
#  tensor([[1.9706],
#         [2.2743]], requires_grad=True)
# Step 158, theta:
#  tensor([[1.9745],
#         [2.2742]], requires_grad=True)
# Step 159, theta:
#  tensor([[1.9784],
#         [2.2742]], requires_grad=True)
# Step 160, theta:
#  tensor([[1.9823],
#         [2.2741]], requires_grad=True)
# Step 161, theta:
#  tensor([[1.9861],
#         [2.2740]], requires_grad=True)
# Step 162, theta:
#  tensor([[1.9900],
#         [2.2739]], requires_grad=True)
# Step 163, theta:
#  tensor([[1.9939],
#         [2.2739]], requires_grad=True)
# Step 164, theta:
#  tensor([[1.9977],
#         [2.2738]], requires_grad=True)
# Step 165, theta:
#  tensor([[2.0015],
#         [2.2737]], requires_grad=True)
# Step 166, theta:
#  tensor([[2.0054],
#         [2.2736]], requires_grad=True)
# Step 167, theta:
#  tensor([[2.0092],
#         [2.2736]], requires_grad=True)
# Step 168, theta:
#  tensor([[2.0130],
#         [2.2735]], requires_grad=True)
# Step 169, theta:
#  tensor([[2.0168],
#         [2.2734]], requires_grad=True)
# Step 170, theta:
#  tensor([[2.0206],
#         [2.2734]], requires_grad=True)
# Step 171, theta:
#  tensor([[2.0244],
#         [2.2733]], requires_grad=True)
# Step 172, theta:
#  tensor([[2.0282],
#         [2.2732]], requires_grad=True)
# Step 173, theta:
#  tensor([[2.0320],
#         [2.2732]], requires_grad=True)
# Step 174, theta:
#  tensor([[2.0357],
#         [2.2731]], requires_grad=True)
# Step 175, theta:
#  tensor([[2.0395],
#         [2.2730]], requires_grad=True)
# Step 176, theta:
#  tensor([[2.0433],
#         [2.2730]], requires_grad=True)
# Step 177, theta:
#  tensor([[2.0470],
#         [2.2729]], requires_grad=True)
# Step 178, theta:
#  tensor([[2.0507],
#         [2.2728]], requires_grad=True)
# Step 179, theta:
#  tensor([[2.0545],
#         [2.2728]], requires_grad=True)
# Step 180, theta:
#  tensor([[2.0582],
#         [2.2727]], requires_grad=True)
# Step 181, theta:
#  tensor([[2.0619],
#         [2.2726]], requires_grad=True)
# Step 182, theta:
#  tensor([[2.0656],
#         [2.2726]], requires_grad=True)
# Step 183, theta:
#  tensor([[2.0693],
#         [2.2725]], requires_grad=True)
# Step 184, theta:
#  tensor([[2.0730],
#         [2.2725]], requires_grad=True)
# Step 185, theta:
#  tensor([[2.0767],
#         [2.2724]], requires_grad=True)
# Step 186, theta:
#  tensor([[2.0804],
#         [2.2723]], requires_grad=True)
# Step 187, theta:
#  tensor([[2.0840],
#         [2.2723]], requires_grad=True)
# Step 188, theta:
#  tensor([[2.0877],
#         [2.2722]], requires_grad=True)
# Step 189, theta:
#  tensor([[2.0914],
#         [2.2722]], requires_grad=True)
# Step 190, theta:
#  tensor([[2.0950],
#         [2.2721]], requires_grad=True)
# Step 191, theta:
#  tensor([[2.0987],
#         [2.2721]], requires_grad=True)
# Step 192, theta:
#  tensor([[2.1023],
#         [2.2720]], requires_grad=True)
# Step 193, theta:
#  tensor([[2.1059],
#         [2.2720]], requires_grad=True)
# Step 194, theta:
#  tensor([[2.1095],
#         [2.2719]], requires_grad=True)
# Step 195, theta:
#  tensor([[2.1132],
#         [2.2719]], requires_grad=True)
# Step 196, theta:
#  tensor([[2.1168],
#         [2.2718]], requires_grad=True)
# Step 197, theta:
#  tensor([[2.1204],
#         [2.2717]], requires_grad=True)
# Step 198, theta:
#  tensor([[2.1240],
#         [2.2717]], requires_grad=True)
# Step 199, theta:
#  tensor([[2.1275],
#         [2.2716]], requires_grad=True)
# Step 200, theta:
#  tensor([[2.1311],
#         [2.2716]], requires_grad=True)
# Step 201, theta:
#  tensor([[2.1347],
#         [2.2715]], requires_grad=True)
# Step 202, theta:
#  tensor([[2.1383],
#         [2.2715]], requires_grad=True)
# Step 203, theta:
#  tensor([[2.1418],
#         [2.2715]], requires_grad=True)
# Step 204, theta:
#  tensor([[2.1454],
#         [2.2714]], requires_grad=True)
# Step 205, theta:
#  tensor([[2.1489],
#         [2.2714]], requires_grad=True)
# Step 206, theta:
#  tensor([[2.1524],
#         [2.2713]], requires_grad=True)
# Step 207, theta:
#  tensor([[2.1560],
#         [2.2713]], requires_grad=True)
# Step 208, theta:
#  tensor([[2.1595],
#         [2.2712]], requires_grad=True)
# Step 209, theta:
#  tensor([[2.1630],
#         [2.2712]], requires_grad=True)
# Step 210, theta:
#  tensor([[2.1665],
#         [2.2711]], requires_grad=True)
# Step 211, theta:
#  tensor([[2.1700],
#         [2.2711]], requires_grad=True)
# Step 212, theta:
#  tensor([[2.1735],
#         [2.2711]], requires_grad=True)
# Step 213, theta:
#  tensor([[2.1770],
#         [2.2710]], requires_grad=True)
# Step 214, theta:
#  tensor([[2.1805],
#         [2.2710]], requires_grad=True)
# Step 215, theta:
#  tensor([[2.1839],
#         [2.2709]], requires_grad=True)
# Step 216, theta:
#  tensor([[2.1874],
#         [2.2709]], requires_grad=True)
# Step 217, theta:
#  tensor([[2.1909],
#         [2.2709]], requires_grad=True)
# Step 218, theta:
#  tensor([[2.1943],
#         [2.2708]], requires_grad=True)
# Step 219, theta:
#  tensor([[2.1977],
#         [2.2708]], requires_grad=True)
# Step 220, theta:
#  tensor([[2.2012],
#         [2.2707]], requires_grad=True)
# Step 221, theta:
#  tensor([[2.2046],
#         [2.2707]], requires_grad=True)
# Step 222, theta:
#  tensor([[2.2080],
#         [2.2707]], requires_grad=True)
# Step 223, theta:
#  tensor([[2.2115],
#         [2.2706]], requires_grad=True)
# Step 224, theta:
#  tensor([[2.2149],
#         [2.2706]], requires_grad=True)
# Step 225, theta:
#  tensor([[2.2183],
#         [2.2706]], requires_grad=True)
# Step 226, theta:
#  tensor([[2.2217],
#         [2.2705]], requires_grad=True)
# Step 227, theta:
#  tensor([[2.2250],
#         [2.2705]], requires_grad=True)
# Step 228, theta:
#  tensor([[2.2284],
#         [2.2705]], requires_grad=True)
# Step 229, theta:
#  tensor([[2.2318],
#         [2.2704]], requires_grad=True)
# Step 230, theta:
#  tensor([[2.2352],
#         [2.2704]], requires_grad=True)
# Step 231, theta:
#  tensor([[2.2385],
#         [2.2704]], requires_grad=True)
# Step 232, theta:
#  tensor([[2.2419],
#         [2.2703]], requires_grad=True)
# Step 233, theta:
#  tensor([[2.2452],
#         [2.2703]], requires_grad=True)
# Step 234, theta:
#  tensor([[2.2486],
#         [2.2703]], requires_grad=True)
# Step 235, theta:
#  tensor([[2.2519],
#         [2.2703]], requires_grad=True)
# Step 236, theta:
#  tensor([[2.2552],
#         [2.2702]], requires_grad=True)
# Step 237, theta:
#  tensor([[2.2586],
#         [2.2702]], requires_grad=True)
# Step 238, theta:
#  tensor([[2.2619],
#         [2.2702]], requires_grad=True)
# Step 239, theta:
#  tensor([[2.2652],
#         [2.2702]], requires_grad=True)
# Step 240, theta:
#  tensor([[2.2685],
#         [2.2701]], requires_grad=True)
# Step 241, theta:
#  tensor([[2.2718],
#         [2.2701]], requires_grad=True)
# Step 242, theta:
#  tensor([[2.2751],
#         [2.2701]], requires_grad=True)
# Step 243, theta:
#  tensor([[2.2784],
#         [2.2701]], requires_grad=True)
# Step 244, theta:
#  tensor([[2.2816],
#         [2.2700]], requires_grad=True)
# Step 245, theta:
#  tensor([[2.2849],
#         [2.2700]], requires_grad=True)
# Step 246, theta:
#  tensor([[2.2882],
#         [2.2700]], requires_grad=True)
# Step 247, theta:
#  tensor([[2.2914],
#         [2.2700]], requires_grad=True)
# Step 248, theta:
#  tensor([[2.2947],
#         [2.2700]], requires_grad=True)
# Step 249, theta:
#  tensor([[2.2979],
#         [2.2699]], requires_grad=True)
# Step 250, theta:
#  tensor([[2.3011],
#         [2.2699]], requires_grad=True)
# Step 251, theta:
#  tensor([[2.3044],
#         [2.2699]], requires_grad=True)
# Step 252, theta:
#  tensor([[2.3076],
#         [2.2699]], requires_grad=True)
# Step 253, theta:
#  tensor([[2.3108],
#         [2.2699]], requires_grad=True)
# Step 254, theta:
#  tensor([[2.3140],
#         [2.2698]], requires_grad=True)
# Step 255, theta:
#  tensor([[2.3172],
#         [2.2698]], requires_grad=True)
# Step 256, theta:
#  tensor([[2.3204],
#         [2.2698]], requires_grad=True)
# Step 257, theta:
#  tensor([[2.3236],
#         [2.2698]], requires_grad=True)
# Step 258, theta:
#  tensor([[2.3268],
#         [2.2698]], requires_grad=True)
# Step 259, theta:
#  tensor([[2.3300],
#         [2.2698]], requires_grad=True)
# Step 260, theta:
#  tensor([[2.3332],
#         [2.2697]], requires_grad=True)
# Step 261, theta:
#  tensor([[2.3363],
#         [2.2697]], requires_grad=True)
# Step 262, theta:
#  tensor([[2.3395],
#         [2.2697]], requires_grad=True)
# Step 263, theta:
#  tensor([[2.3426],
#         [2.2697]], requires_grad=True)
# Step 264, theta:
#  tensor([[2.3458],
#         [2.2697]], requires_grad=True)
# Step 265, theta:
#  tensor([[2.3489],
#         [2.2697]], requires_grad=True)
# Step 266, theta:
#  tensor([[2.3521],
#         [2.2697]], requires_grad=True)
# Step 267, theta:
#  tensor([[2.3552],
#         [2.2697]], requires_grad=True)
# Step 268, theta:
#  tensor([[2.3583],
#         [2.2697]], requires_grad=True)
# Step 269, theta:
#  tensor([[2.3614],
#         [2.2696]], requires_grad=True)
# Step 270, theta:
#  tensor([[2.3645],
#         [2.2696]], requires_grad=True)
# Step 271, theta:
#  tensor([[2.3676],
#         [2.2696]], requires_grad=True)
# Step 272, theta:
#  tensor([[2.3707],
#         [2.2696]], requires_grad=True)
# Step 273, theta:
#  tensor([[2.3738],
#         [2.2696]], requires_grad=True)
# Step 274, theta:
#  tensor([[2.3769],
#         [2.2696]], requires_grad=True)
# Step 275, theta:
#  tensor([[2.3800],
#         [2.2696]], requires_grad=True)
# Step 276, theta:
#  tensor([[2.3831],
#         [2.2696]], requires_grad=True)
# Step 277, theta:
#  tensor([[2.3861],
#         [2.2696]], requires_grad=True)
# Step 278, theta:
#  tensor([[2.3892],
#         [2.2696]], requires_grad=True)
# Step 279, theta:
#  tensor([[2.3922],
#         [2.2696]], requires_grad=True)
# Step 280, theta:
#  tensor([[2.3953],
#         [2.2696]], requires_grad=True)
# Step 281, theta:
#  tensor([[2.3983],
#         [2.2696]], requires_grad=True)
# Step 282, theta:
#  tensor([[2.4014],
#         [2.2696]], requires_grad=True)
# Step 283, theta:
#  tensor([[2.4044],
#         [2.2696]], requires_grad=True)
# Step 284, theta:
#  tensor([[2.4074],
#         [2.2696]], requires_grad=True)
# Step 285, theta:
#  tensor([[2.4104],
#         [2.2696]], requires_grad=True)
# Step 286, theta:
#  tensor([[2.4134],
#         [2.2696]], requires_grad=True)
# Step 287, theta:
#  tensor([[2.4164],
#         [2.2696]], requires_grad=True)
# Step 288, theta:
#  tensor([[2.4194],
#         [2.2696]], requires_grad=True)
# Step 289, theta:
#  tensor([[2.4224],
#         [2.2696]], requires_grad=True)
# Step 290, theta:
#  tensor([[2.4254],
#         [2.2696]], requires_grad=True)
# Step 291, theta:
#  tensor([[2.4284],
#         [2.2696]], requires_grad=True)
# Step 292, theta:
#  tensor([[2.4314],
#         [2.2696]], requires_grad=True)
# Step 293, theta:
#  tensor([[2.4344],
#         [2.2696]], requires_grad=True)
# Step 294, theta:
#  tensor([[2.4373],
#         [2.2696]], requires_grad=True)
# Step 295, theta:
#  tensor([[2.4403],
#         [2.2696]], requires_grad=True)
# Step 296, theta:
#  tensor([[2.4432],
#         [2.2696]], requires_grad=True)
# Step 297, theta:
#  tensor([[2.4462],
#         [2.2696]], requires_grad=True)
# Step 298, theta:
#  tensor([[2.4491],
#         [2.2696]], requires_grad=True)
# Step 299, theta:
#  tensor([[2.4520],
#         [2.2696]], requires_grad=True)
# Step 300, theta:
#  tensor([[2.4550],
#         [2.2696]], requires_grad=True)
# Step 301, theta:
#  tensor([[2.4579],
#         [2.2696]], requires_grad=True)
# Step 302, theta:
#  tensor([[2.4608],
#         [2.2696]], requires_grad=True)
# Step 303, theta:
#  tensor([[2.4637],
#         [2.2696]], requires_grad=True)
# Step 304, theta:
#  tensor([[2.4666],
#         [2.2697]], requires_grad=True)
# Step 305, theta:
#  tensor([[2.4695],
#         [2.2697]], requires_grad=True)
# Step 306, theta:
#  tensor([[2.4724],
#         [2.2697]], requires_grad=True)
# Step 307, theta:
#  tensor([[2.4753],
#         [2.2697]], requires_grad=True)
# Step 308, theta:
#  tensor([[2.4782],
#         [2.2697]], requires_grad=True)
# Step 309, theta:
#  tensor([[2.4811],
#         [2.2697]], requires_grad=True)
# Step 310, theta:
#  tensor([[2.4839],
#         [2.2697]], requires_grad=True)
# Step 311, theta:
#  tensor([[2.4868],
#         [2.2697]], requires_grad=True)
# Step 312, theta:
#  tensor([[2.4897],
#         [2.2697]], requires_grad=True)
# Step 313, theta:
#  tensor([[2.4925],
#         [2.2698]], requires_grad=True)
# Step 314, theta:
#  tensor([[2.4954],
#         [2.2698]], requires_grad=True)
# Step 315, theta:
#  tensor([[2.4982],
#         [2.2698]], requires_grad=True)
# Step 316, theta:
#  tensor([[2.5010],
#         [2.2698]], requires_grad=True)
# Step 317, theta:
#  tensor([[2.5039],
#         [2.2698]], requires_grad=True)
# Step 318, theta:
#  tensor([[2.5067],
#         [2.2698]], requires_grad=True)
# Step 319, theta:
#  tensor([[2.5095],
#         [2.2698]], requires_grad=True)
# Step 320, theta:
#  tensor([[2.5123],
#         [2.2699]], requires_grad=True)
# Step 321, theta:
#  tensor([[2.5151],
#         [2.2699]], requires_grad=True)
# Step 322, theta:
#  tensor([[2.5179],
#         [2.2699]], requires_grad=True)
# Step 323, theta:
#  tensor([[2.5207],
#         [2.2699]], requires_grad=True)
# Step 324, theta:
#  tensor([[2.5235],
#         [2.2699]], requires_grad=True)
# Step 325, theta:
#  tensor([[2.5263],
#         [2.2700]], requires_grad=True)
# Step 326, theta:
#  tensor([[2.5291],
#         [2.2700]], requires_grad=True)
# Step 327, theta:
#  tensor([[2.5318],
#         [2.2700]], requires_grad=True)
# Step 328, theta:
#  tensor([[2.5346],
#         [2.2700]], requires_grad=True)
# Step 329, theta:
#  tensor([[2.5374],
#         [2.2700]], requires_grad=True)
# Step 330, theta:
#  tensor([[2.5401],
#         [2.2701]], requires_grad=True)
# Step 331, theta:
#  tensor([[2.5429],
#         [2.2701]], requires_grad=True)
# Step 332, theta:
#  tensor([[2.5456],
#         [2.2701]], requires_grad=True)
# Step 333, theta:
#  tensor([[2.5484],
#         [2.2701]], requires_grad=True)
# Step 334, theta:
#  tensor([[2.5511],
#         [2.2701]], requires_grad=True)
# Step 335, theta:
#  tensor([[2.5538],
#         [2.2702]], requires_grad=True)
# Step 336, theta:
#  tensor([[2.5566],
#         [2.2702]], requires_grad=True)
# Step 337, theta:
#  tensor([[2.5593],
#         [2.2702]], requires_grad=True)
# Step 338, theta:
#  tensor([[2.5620],
#         [2.2702]], requires_grad=True)
# Step 339, theta:
#  tensor([[2.5647],
#         [2.2703]], requires_grad=True)
# Step 340, theta:
#  tensor([[2.5674],
#         [2.2703]], requires_grad=True)
# Step 341, theta:
#  tensor([[2.5701],
#         [2.2703]], requires_grad=True)
# Step 342, theta:
#  tensor([[2.5728],
#         [2.2703]], requires_grad=True)
# Step 343, theta:
#  tensor([[2.5755],
#         [2.2704]], requires_grad=True)
# Step 344, theta:
#  tensor([[2.5782],
#         [2.2704]], requires_grad=True)
# Step 345, theta:
#  tensor([[2.5808],
#         [2.2704]], requires_grad=True)
# Step 346, theta:
#  tensor([[2.5835],
#         [2.2705]], requires_grad=True)
# Step 347, theta:
#  tensor([[2.5862],
#         [2.2705]], requires_grad=True)
# Step 348, theta:
#  tensor([[2.5888],
#         [2.2705]], requires_grad=True)
# Step 349, theta:
#  tensor([[2.5915],
#         [2.2705]], requires_grad=True)
# Step 350, theta:
#  tensor([[2.5941],
#         [2.2706]], requires_grad=True)
# Step 351, theta:
#  tensor([[2.5968],
#         [2.2706]], requires_grad=True)
# Step 352, theta:
#  tensor([[2.5994],
#         [2.2706]], requires_grad=True)
# Step 353, theta:
#  tensor([[2.6021],
#         [2.2707]], requires_grad=True)
# Step 354, theta:
#  tensor([[2.6047],
#         [2.2707]], requires_grad=True)
# Step 355, theta:
#  tensor([[2.6073],
#         [2.2707]], requires_grad=True)
# Step 356, theta:
#  tensor([[2.6099],
#         [2.2708]], requires_grad=True)
# Step 357, theta:
#  tensor([[2.6125],
#         [2.2708]], requires_grad=True)
# Step 358, theta:
#  tensor([[2.6151],
#         [2.2708]], requires_grad=True)
# Step 359, theta:
#  tensor([[2.6177],
#         [2.2709]], requires_grad=True)
# Step 360, theta:
#  tensor([[2.6203],
#         [2.2709]], requires_grad=True)
# Step 361, theta:
#  tensor([[2.6229],
#         [2.2709]], requires_grad=True)
# Step 362, theta:
#  tensor([[2.6255],
#         [2.2710]], requires_grad=True)
# Step 363, theta:
#  tensor([[2.6281],
#         [2.2710]], requires_grad=True)
# Step 364, theta:
#  tensor([[2.6307],
#         [2.2710]], requires_grad=True)
# Step 365, theta:
#  tensor([[2.6332],
#         [2.2711]], requires_grad=True)
# Step 366, theta:
#  tensor([[2.6358],
#         [2.2711]], requires_grad=True)
# Step 367, theta:
#  tensor([[2.6384],
#         [2.2711]], requires_grad=True)
# Step 368, theta:
#  tensor([[2.6409],
#         [2.2712]], requires_grad=True)
# Step 369, theta:
#  tensor([[2.6435],
#         [2.2712]], requires_grad=True)
# Step 370, theta:
#  tensor([[2.6460],
#         [2.2713]], requires_grad=True)
# Step 371, theta:
#  tensor([[2.6486],
#         [2.2713]], requires_grad=True)
# Step 372, theta:
#  tensor([[2.6511],
#         [2.2713]], requires_grad=True)
# Step 373, theta:
#  tensor([[2.6536],
#         [2.2714]], requires_grad=True)
# Step 374, theta:
#  tensor([[2.6562],
#         [2.2714]], requires_grad=True)
# Step 375, theta:
#  tensor([[2.6587],
#         [2.2715]], requires_grad=True)
# Step 376, theta:
#  tensor([[2.6612],
#         [2.2715]], requires_grad=True)
# Step 377, theta:
#  tensor([[2.6637],
#         [2.2715]], requires_grad=True)
# Step 378, theta:
#  tensor([[2.6662],
#         [2.2716]], requires_grad=True)
# Step 379, theta:
#  tensor([[2.6687],
#         [2.2716]], requires_grad=True)
# Step 380, theta:
#  tensor([[2.6712],
#         [2.2717]], requires_grad=True)
# Step 381, theta:
#  tensor([[2.6737],
#         [2.2717]], requires_grad=True)
# Step 382, theta:
#  tensor([[2.6762],
#         [2.2717]], requires_grad=True)
# Step 383, theta:
#  tensor([[2.6787],
#         [2.2718]], requires_grad=True)
# Step 384, theta:
#  tensor([[2.6811],
#         [2.2718]], requires_grad=True)
# Step 385, theta:
#  tensor([[2.6836],
#         [2.2719]], requires_grad=True)
# Step 386, theta:
#  tensor([[2.6861],
#         [2.2719]], requires_grad=True)
# Step 387, theta:
#  tensor([[2.6885],
#         [2.2720]], requires_grad=True)
# Step 388, theta:
#  tensor([[2.6910],
#         [2.2720]], requires_grad=True)
# Step 389, theta:
#  tensor([[2.6934],
#         [2.2721]], requires_grad=True)
# Step 390, theta:
#  tensor([[2.6959],
#         [2.2721]], requires_grad=True)
# Step 391, theta:
#  tensor([[2.6983],
#         [2.2722]], requires_grad=True)
# Step 392, theta:
#  tensor([[2.7007],
#         [2.2722]], requires_grad=True)
# Step 393, theta:
#  tensor([[2.7032],
#         [2.2722]], requires_grad=True)
# Step 394, theta:
#  tensor([[2.7056],
#         [2.2723]], requires_grad=True)
# Step 395, theta:
#  tensor([[2.7080],
#         [2.2723]], requires_grad=True)
# Step 396, theta:
#  tensor([[2.7104],
#         [2.2724]], requires_grad=True)
# Step 397, theta:
#  tensor([[2.7129],
#         [2.2724]], requires_grad=True)
# Step 398, theta:
#  tensor([[2.7153],
#         [2.2725]], requires_grad=True)
# Step 399, theta:
#  tensor([[2.7177],
#         [2.2725]], requires_grad=True)
# Step 400, theta:
#  tensor([[2.7201],
#         [2.2726]], requires_grad=True)
# Step 401, theta:
#  tensor([[2.7225],
#         [2.2726]], requires_grad=True)
# Step 402, theta:
#  tensor([[2.7248],
#         [2.2727]], requires_grad=True)
# Step 403, theta:
#  tensor([[2.7272],
#         [2.2727]], requires_grad=True)
# Step 404, theta:
#  tensor([[2.7296],
#         [2.2728]], requires_grad=True)
# Step 405, theta:
#  tensor([[2.7320],
#         [2.2728]], requires_grad=True)
# Step 406, theta:
#  tensor([[2.7343],
#         [2.2729]], requires_grad=True)
# Step 407, theta:
#  tensor([[2.7367],
#         [2.2730]], requires_grad=True)
# Step 408, theta:
#  tensor([[2.7391],
#         [2.2730]], requires_grad=True)
# Step 409, theta:
#  tensor([[2.7414],
#         [2.2731]], requires_grad=True)
# Step 410, theta:
#  tensor([[2.7438],
#         [2.2731]], requires_grad=True)
# Step 411, theta:
#  tensor([[2.7461],
#         [2.2732]], requires_grad=True)
# Step 412, theta:
#  tensor([[2.7485],
#         [2.2732]], requires_grad=True)
# Step 413, theta:
#  tensor([[2.7508],
#         [2.2733]], requires_grad=True)
# Step 414, theta:
#  tensor([[2.7531],
#         [2.2733]], requires_grad=True)
# Step 415, theta:
#  tensor([[2.7554],
#         [2.2734]], requires_grad=True)
# Step 416, theta:
#  tensor([[2.7578],
#         [2.2734]], requires_grad=True)
# Step 417, theta:
#  tensor([[2.7601],
#         [2.2735]], requires_grad=True)
# Step 418, theta:
#  tensor([[2.7624],
#         [2.2736]], requires_grad=True)
# Step 419, theta:
#  tensor([[2.7647],
#         [2.2736]], requires_grad=True)
# Step 420, theta:
#  tensor([[2.7670],
#         [2.2737]], requires_grad=True)
# Step 421, theta:
#  tensor([[2.7693],
#         [2.2737]], requires_grad=True)
# Step 422, theta:
#  tensor([[2.7716],
#         [2.2738]], requires_grad=True)
# Step 423, theta:
#  tensor([[2.7739],
#         [2.2738]], requires_grad=True)
# Step 424, theta:
#  tensor([[2.7762],
#         [2.2739]], requires_grad=True)
# Step 425, theta:
#  tensor([[2.7785],
#         [2.2740]], requires_grad=True)
# Step 426, theta:
#  tensor([[2.7807],
#         [2.2740]], requires_grad=True)
# Step 427, theta:
#  tensor([[2.7830],
#         [2.2741]], requires_grad=True)
# Step 428, theta:
#  tensor([[2.7853],
#         [2.2741]], requires_grad=True)
# Step 429, theta:
#  tensor([[2.7875],
#         [2.2742]], requires_grad=True)
# Step 430, theta:
#  tensor([[2.7898],
#         [2.2743]], requires_grad=True)
# Step 431, theta:
#  tensor([[2.7920],
#         [2.2743]], requires_grad=True)
# Step 432, theta:
#  tensor([[2.7943],
#         [2.2744]], requires_grad=True)
# Step 433, theta:
#  tensor([[2.7965],
#         [2.2744]], requires_grad=True)
# Step 434, theta:
#  tensor([[2.7988],
#         [2.2745]], requires_grad=True)
# Step 435, theta:
#  tensor([[2.8010],
#         [2.2746]], requires_grad=True)
# Step 436, theta:
#  tensor([[2.8032],
#         [2.2746]], requires_grad=True)
# Step 437, theta:
#  tensor([[2.8055],
#         [2.2747]], requires_grad=True)
# Step 438, theta:
#  tensor([[2.8077],
#         [2.2748]], requires_grad=True)
# Step 439, theta:
#  tensor([[2.8099],
#         [2.2748]], requires_grad=True)
# Step 440, theta:
#  tensor([[2.8121],
#         [2.2749]], requires_grad=True)
# Step 441, theta:
#  tensor([[2.8143],
#         [2.2750]], requires_grad=True)
# Step 442, theta:
#  tensor([[2.8165],
#         [2.2750]], requires_grad=True)
# Step 443, theta:
#  tensor([[2.8187],
#         [2.2751]], requires_grad=True)
# Step 444, theta:
#  tensor([[2.8209],
#         [2.2752]], requires_grad=True)
# Step 445, theta:
#  tensor([[2.8231],
#         [2.2752]], requires_grad=True)
# Step 446, theta:
#  tensor([[2.8253],
#         [2.2753]], requires_grad=True)
# Step 447, theta:
#  tensor([[2.8275],
#         [2.2754]], requires_grad=True)
# Step 448, theta:
#  tensor([[2.8297],
#         [2.2754]], requires_grad=True)
# Step 449, theta:
#  tensor([[2.8318],
#         [2.2755]], requires_grad=True)
# Step 450, theta:
#  tensor([[2.8340],
#         [2.2756]], requires_grad=True)
# Step 451, theta:
#  tensor([[2.8362],
#         [2.2756]], requires_grad=True)
# Step 452, theta:
#  tensor([[2.8383],
#         [2.2757]], requires_grad=True)
# Step 453, theta:
#  tensor([[2.8405],
#         [2.2758]], requires_grad=True)
# Step 454, theta:
#  tensor([[2.8426],
#         [2.2758]], requires_grad=True)
# Step 455, theta:
#  tensor([[2.8448],
#         [2.2759]], requires_grad=True)
# Step 456, theta:
#  tensor([[2.8469],
#         [2.2760]], requires_grad=True)
# Step 457, theta:
#  tensor([[2.8491],
#         [2.2760]], requires_grad=True)
# Step 458, theta:
#  tensor([[2.8512],
#         [2.2761]], requires_grad=True)
# Step 459, theta:
#  tensor([[2.8533],
#         [2.2762]], requires_grad=True)
# Step 460, theta:
#  tensor([[2.8555],
#         [2.2762]], requires_grad=True)
# Step 461, theta:
#  tensor([[2.8576],
#         [2.2763]], requires_grad=True)
# Step 462, theta:
#  tensor([[2.8597],
#         [2.2764]], requires_grad=True)
# Step 463, theta:
#  tensor([[2.8618],
#         [2.2765]], requires_grad=True)
# Step 464, theta:
#  tensor([[2.8639],
#         [2.2765]], requires_grad=True)
# Step 465, theta:
#  tensor([[2.8660],
#         [2.2766]], requires_grad=True)
# Step 466, theta:
#  tensor([[2.8681],
#         [2.2767]], requires_grad=True)
# Step 467, theta:
#  tensor([[2.8702],
#         [2.2767]], requires_grad=True)
# Step 468, theta:
#  tensor([[2.8723],
#         [2.2768]], requires_grad=True)
# Step 469, theta:
#  tensor([[2.8744],
#         [2.2769]], requires_grad=True)
# Step 470, theta:
#  tensor([[2.8765],
#         [2.2770]], requires_grad=True)
# Step 471, theta:
#  tensor([[2.8786],
#         [2.2770]], requires_grad=True)
# Step 472, theta:
#  tensor([[2.8807],
#         [2.2771]], requires_grad=True)
# Step 473, theta:
#  tensor([[2.8827],
#         [2.2772]], requires_grad=True)
# Step 474, theta:
#  tensor([[2.8848],
#         [2.2773]], requires_grad=True)
# Step 475, theta:
#  tensor([[2.8869],
#         [2.2773]], requires_grad=True)
# Step 476, theta:
#  tensor([[2.8889],
#         [2.2774]], requires_grad=True)
# Step 477, theta:
#  tensor([[2.8910],
#         [2.2775]], requires_grad=True)
# Step 478, theta:
#  tensor([[2.8930],
#         [2.2776]], requires_grad=True)
# Step 479, theta:
#  tensor([[2.8951],
#         [2.2776]], requires_grad=True)
# Step 480, theta:
#  tensor([[2.8971],
#         [2.2777]], requires_grad=True)
# Step 481, theta:
#  tensor([[2.8991],
#         [2.2778]], requires_grad=True)
# Step 482, theta:
#  tensor([[2.9012],
#         [2.2779]], requires_grad=True)
# Step 483, theta:
#  tensor([[2.9032],
#         [2.2780]], requires_grad=True)
# Step 484, theta:
#  tensor([[2.9052],
#         [2.2780]], requires_grad=True)
# Step 485, theta:
#  tensor([[2.9073],
#         [2.2781]], requires_grad=True)
# Step 486, theta:
#  tensor([[2.9093],
#         [2.2782]], requires_grad=True)
# Step 487, theta:
#  tensor([[2.9113],
#         [2.2783]], requires_grad=True)
# Step 488, theta:
#  tensor([[2.9133],
#         [2.2784]], requires_grad=True)
# Step 489, theta:
#  tensor([[2.9153],
#         [2.2784]], requires_grad=True)
# Step 490, theta:
#  tensor([[2.9173],
#         [2.2785]], requires_grad=True)
# Step 491, theta:
#  tensor([[2.9193],
#         [2.2786]], requires_grad=True)
# Step 492, theta:
#  tensor([[2.9213],
#         [2.2787]], requires_grad=True)
# Step 493, theta:
#  tensor([[2.9233],
#         [2.2788]], requires_grad=True)
# Step 494, theta:
#  tensor([[2.9253],
#         [2.2788]], requires_grad=True)
# Step 495, theta:
#  tensor([[2.9273],
#         [2.2789]], requires_grad=True)
# Step 496, theta:
#  tensor([[2.9293],
#         [2.2790]], requires_grad=True)
# Step 497, theta:
#  tensor([[2.9312],
#         [2.2791]], requires_grad=True)
# Step 498, theta:
#  tensor([[2.9332],
#         [2.2792]], requires_grad=True)
# Step 499, theta:
#  tensor([[2.9352],
#         [2.2792]], requires_grad=True)
# Step 500, theta:
#  tensor([[2.9371],
#         [2.2793]], requires_grad=True)
# Step 501, theta:
#  tensor([[2.9391],
#         [2.2794]], requires_grad=True)
# Step 502, theta:
#  tensor([[2.9410],
#         [2.2795]], requires_grad=True)
# Step 503, theta:
#  tensor([[2.9430],
#         [2.2796]], requires_grad=True)
# Step 504, theta:
#  tensor([[2.9449],
#         [2.2797]], requires_grad=True)
# Step 505, theta:
#  tensor([[2.9469],
#         [2.2797]], requires_grad=True)
# Step 506, theta:
#  tensor([[2.9488],
#         [2.2798]], requires_grad=True)
# Step 507, theta:
#  tensor([[2.9508],
#         [2.2799]], requires_grad=True)
# Step 508, theta:
#  tensor([[2.9527],
#         [2.2800]], requires_grad=True)
# Step 509, theta:
#  tensor([[2.9546],
#         [2.2801]], requires_grad=True)
# Step 510, theta:
#  tensor([[2.9565],
#         [2.2802]], requires_grad=True)
# Step 511, theta:
#  tensor([[2.9585],
#         [2.2803]], requires_grad=True)
# Step 512, theta:
#  tensor([[2.9604],
#         [2.2803]], requires_grad=True)
# Step 513, theta:
#  tensor([[2.9623],
#         [2.2804]], requires_grad=True)
# Step 514, theta:
#  tensor([[2.9642],
#         [2.2805]], requires_grad=True)
# Step 515, theta:
#  tensor([[2.9661],
#         [2.2806]], requires_grad=True)
# Step 516, theta:
#  tensor([[2.9680],
#         [2.2807]], requires_grad=True)
# Step 517, theta:
#  tensor([[2.9699],
#         [2.2808]], requires_grad=True)
# Step 518, theta:
#  tensor([[2.9718],
#         [2.2809]], requires_grad=True)
# Step 519, theta:
#  tensor([[2.9737],
#         [2.2809]], requires_grad=True)
# Step 520, theta:
#  tensor([[2.9756],
#         [2.2810]], requires_grad=True)
# Step 521, theta:
#  tensor([[2.9775],
#         [2.2811]], requires_grad=True)
# Step 522, theta:
#  tensor([[2.9793],
#         [2.2812]], requires_grad=True)
# Step 523, theta:
#  tensor([[2.9812],
#         [2.2813]], requires_grad=True)
# Step 524, theta:
#  tensor([[2.9831],
#         [2.2814]], requires_grad=True)
# Step 525, theta:
#  tensor([[2.9850],
#         [2.2815]], requires_grad=True)
# Step 526, theta:
#  tensor([[2.9868],
#         [2.2816]], requires_grad=True)
# Step 527, theta:
#  tensor([[2.9887],
#         [2.2817]], requires_grad=True)
# Step 528, theta:
#  tensor([[2.9905],
#         [2.2817]], requires_grad=True)
# Step 529, theta:
#  tensor([[2.9924],
#         [2.2818]], requires_grad=True)
# Step 530, theta:
#  tensor([[2.9942],
#         [2.2819]], requires_grad=True)
# Step 531, theta:
#  tensor([[2.9961],
#         [2.2820]], requires_grad=True)
# Step 532, theta:
#  tensor([[2.9979],
#         [2.2821]], requires_grad=True)
# Step 533, theta:
#  tensor([[2.9998],
#         [2.2822]], requires_grad=True)
# Step 534, theta:
#  tensor([[3.0016],
#         [2.2823]], requires_grad=True)
# Step 535, theta:
#  tensor([[3.0034],
#         [2.2824]], requires_grad=True)
# Step 536, theta:
#  tensor([[3.0053],
#         [2.2825]], requires_grad=True)
# Step 537, theta:
#  tensor([[3.0071],
#         [2.2826]], requires_grad=True)
# Step 538, theta:
#  tensor([[3.0089],
#         [2.2827]], requires_grad=True)
# Step 539, theta:
#  tensor([[3.0107],
#         [2.2828]], requires_grad=True)
# Step 540, theta:
#  tensor([[3.0125],
#         [2.2829]], requires_grad=True)
# Step 541, theta:
#  tensor([[3.0143],
#         [2.2829]], requires_grad=True)
# Step 542, theta:
#  tensor([[3.0161],
#         [2.2830]], requires_grad=True)
# Step 543, theta:
#  tensor([[3.0179],
#         [2.2831]], requires_grad=True)
# Step 544, theta:
#  tensor([[3.0197],
#         [2.2832]], requires_grad=True)
# Step 545, theta:
#  tensor([[3.0215],
#         [2.2833]], requires_grad=True)
# Step 546, theta:
#  tensor([[3.0233],
#         [2.2834]], requires_grad=True)
# Step 547, theta:
#  tensor([[3.0251],
#         [2.2835]], requires_grad=True)
# Step 548, theta:
#  tensor([[3.0269],
#         [2.2836]], requires_grad=True)
# Step 549, theta:
#  tensor([[3.0287],
#         [2.2837]], requires_grad=True)
# Step 550, theta:
#  tensor([[3.0305],
#         [2.2838]], requires_grad=True)
# Step 551, theta:
#  tensor([[3.0322],
#         [2.2839]], requires_grad=True)
# Step 552, theta:
#  tensor([[3.0340],
#         [2.2840]], requires_grad=True)
# Step 553, theta:
#  tensor([[3.0358],
#         [2.2841]], requires_grad=True)
# Step 554, theta:
#  tensor([[3.0375],
#         [2.2842]], requires_grad=True)
# Step 555, theta:
#  tensor([[3.0393],
#         [2.2843]], requires_grad=True)
# Step 556, theta:
#  tensor([[3.0410],
#         [2.2844]], requires_grad=True)
# Step 557, theta:
#  tensor([[3.0428],
#         [2.2845]], requires_grad=True)
# Step 558, theta:
#  tensor([[3.0445],
#         [2.2846]], requires_grad=True)
# Step 559, theta:
#  tensor([[3.0463],
#         [2.2847]], requires_grad=True)
# Step 560, theta:
#  tensor([[3.0480],
#         [2.2848]], requires_grad=True)
# Step 561, theta:
#  tensor([[3.0498],
#         [2.2849]], requires_grad=True)
# Step 562, theta:
#  tensor([[3.0515],
#         [2.2850]], requires_grad=True)
# Step 563, theta:
#  tensor([[3.0532],
#         [2.2851]], requires_grad=True)
# Step 564, theta:
#  tensor([[3.0550],
#         [2.2852]], requires_grad=True)
# Step 565, theta:
#  tensor([[3.0567],
#         [2.2853]], requires_grad=True)
# Step 566, theta:
#  tensor([[3.0584],
#         [2.2854]], requires_grad=True)
# Step 567, theta:
#  tensor([[3.0601],
#         [2.2855]], requires_grad=True)
# Step 568, theta:
#  tensor([[3.0618],
#         [2.2856]], requires_grad=True)
# Step 569, theta:
#  tensor([[3.0635],
#         [2.2857]], requires_grad=True)
# Step 570, theta:
#  tensor([[3.0653],
#         [2.2858]], requires_grad=True)
# Step 571, theta:
#  tensor([[3.0670],
#         [2.2859]], requires_grad=True)
# Step 572, theta:
#  tensor([[3.0687],
#         [2.2860]], requires_grad=True)
# Step 573, theta:
#  tensor([[3.0704],
#         [2.2861]], requires_grad=True)
# Step 574, theta:
#  tensor([[3.0721],
#         [2.2862]], requires_grad=True)
# Step 575, theta:
#  tensor([[3.0737],
#         [2.2863]], requires_grad=True)
# Step 576, theta:
#  tensor([[3.0754],
#         [2.2864]], requires_grad=True)
# Step 577, theta:
#  tensor([[3.0771],
#         [2.2865]], requires_grad=True)
# Step 578, theta:
#  tensor([[3.0788],
#         [2.2866]], requires_grad=True)
# Step 579, theta:
#  tensor([[3.0805],
#         [2.2867]], requires_grad=True)
# Step 580, theta:
#  tensor([[3.0821],
#         [2.2868]], requires_grad=True)
# Step 581, theta:
#  tensor([[3.0838],
#         [2.2869]], requires_grad=True)
# Step 582, theta:
#  tensor([[3.0855],
#         [2.2870]], requires_grad=True)
# Step 583, theta:
#  tensor([[3.0871],
#         [2.2871]], requires_grad=True)
# Step 584, theta:
#  tensor([[3.0888],
#         [2.2872]], requires_grad=True)
# Step 585, theta:
#  tensor([[3.0905],
#         [2.2873]], requires_grad=True)
# Step 586, theta:
#  tensor([[3.0921],
#         [2.2874]], requires_grad=True)
# Step 587, theta:
#  tensor([[3.0938],
#         [2.2875]], requires_grad=True)
# Step 588, theta:
#  tensor([[3.0954],
#         [2.2876]], requires_grad=True)
# Step 589, theta:
#  tensor([[3.0971],
#         [2.2877]], requires_grad=True)
# Step 590, theta:
#  tensor([[3.0987],
#         [2.2878]], requires_grad=True)
# Step 591, theta:
#  tensor([[3.1003],
#         [2.2879]], requires_grad=True)
# Step 592, theta:
#  tensor([[3.1020],
#         [2.2880]], requires_grad=True)
# Step 593, theta:
#  tensor([[3.1036],
#         [2.2881]], requires_grad=True)
# Step 594, theta:
#  tensor([[3.1052],
#         [2.2882]], requires_grad=True)
# Step 595, theta:
#  tensor([[3.1069],
#         [2.2883]], requires_grad=True)
# Step 596, theta:
#  tensor([[3.1085],
#         [2.2884]], requires_grad=True)
# Step 597, theta:
#  tensor([[3.1101],
#         [2.2886]], requires_grad=True)
# Step 598, theta:
#  tensor([[3.1117],
#         [2.2887]], requires_grad=True)
# Step 599, theta:
#  tensor([[3.1133],
#         [2.2888]], requires_grad=True)
# Step 600, theta:
#  tensor([[3.1149],
#         [2.2889]], requires_grad=True)
# Step 601, theta:
#  tensor([[3.1165],
#         [2.2890]], requires_grad=True)
# Step 602, theta:
#  tensor([[3.1181],
#         [2.2891]], requires_grad=True)
# Step 603, theta:
#  tensor([[3.1197],
#         [2.2892]], requires_grad=True)
# Step 604, theta:
#  tensor([[3.1213],
#         [2.2893]], requires_grad=True)
# Step 605, theta:
#  tensor([[3.1229],
#         [2.2894]], requires_grad=True)
# Step 606, theta:
#  tensor([[3.1245],
#         [2.2895]], requires_grad=True)
# Step 607, theta:
#  tensor([[3.1261],
#         [2.2896]], requires_grad=True)
# Step 608, theta:
#  tensor([[3.1277],
#         [2.2897]], requires_grad=True)
# Step 609, theta:
#  tensor([[3.1293],
#         [2.2898]], requires_grad=True)
# Step 610, theta:
#  tensor([[3.1308],
#         [2.2900]], requires_grad=True)
# Step 611, theta:
#  tensor([[3.1324],
#         [2.2901]], requires_grad=True)
# Step 612, theta:
#  tensor([[3.1340],
#         [2.2902]], requires_grad=True)
# Step 613, theta:
#  tensor([[3.1355],
#         [2.2903]], requires_grad=True)
# Step 614, theta:
#  tensor([[3.1371],
#         [2.2904]], requires_grad=True)
# Step 615, theta:
#  tensor([[3.1387],
#         [2.2905]], requires_grad=True)
# Step 616, theta:
#  tensor([[3.1402],
#         [2.2906]], requires_grad=True)
# Step 617, theta:
#  tensor([[3.1418],
#         [2.2907]], requires_grad=True)
# Step 618, theta:
#  tensor([[3.1433],
#         [2.2908]], requires_grad=True)
# Step 619, theta:
#  tensor([[3.1449],
#         [2.2909]], requires_grad=True)
# Step 620, theta:
#  tensor([[3.1464],
#         [2.2911]], requires_grad=True)
# Step 621, theta:
#  tensor([[3.1480],
#         [2.2912]], requires_grad=True)
# Step 622, theta:
#  tensor([[3.1495],
#         [2.2913]], requires_grad=True)
# Step 623, theta:
#  tensor([[3.1511],
#         [2.2914]], requires_grad=True)
# Step 624, theta:
#  tensor([[3.1526],
#         [2.2915]], requires_grad=True)
# Step 625, theta:
#  tensor([[3.1541],
#         [2.2916]], requires_grad=True)
# Step 626, theta:
#  tensor([[3.1556],
#         [2.2917]], requires_grad=True)
# Step 627, theta:
#  tensor([[3.1572],
#         [2.2918]], requires_grad=True)
# Step 628, theta:
#  tensor([[3.1587],
#         [2.2919]], requires_grad=True)
# Step 629, theta:
#  tensor([[3.1602],
#         [2.2921]], requires_grad=True)
# Step 630, theta:
#  tensor([[3.1617],
#         [2.2922]], requires_grad=True)
# Step 631, theta:
#  tensor([[3.1632],
#         [2.2923]], requires_grad=True)
# Step 632, theta:
#  tensor([[3.1647],
#         [2.2924]], requires_grad=True)
# Step 633, theta:
#  tensor([[3.1662],
#         [2.2925]], requires_grad=True)
# Step 634, theta:
#  tensor([[3.1678],
#         [2.2926]], requires_grad=True)
# Step 635, theta:
#  tensor([[3.1693],
#         [2.2927]], requires_grad=True)
# Step 636, theta:
#  tensor([[3.1707],
#         [2.2929]], requires_grad=True)
# Step 637, theta:
#  tensor([[3.1722],
#         [2.2930]], requires_grad=True)
# Step 638, theta:
#  tensor([[3.1737],
#         [2.2931]], requires_grad=True)
# Step 639, theta:
#  tensor([[3.1752],
#         [2.2932]], requires_grad=True)
# Step 640, theta:
#  tensor([[3.1767],
#         [2.2933]], requires_grad=True)
# Step 641, theta:
#  tensor([[3.1782],
#         [2.2934]], requires_grad=True)
# Step 642, theta:
# ...
#  tensor([[3.2338],
#         [2.2980]], requires_grad=True)
# Step 681, theta:
#  tensor([[3.2351],
#         [2.2982]], requires_grad=True)
# Step 682, theta:
#  tensor([[3.2365],
#         [2.2983]], requires_grad=True)
# Step 683, theta:
#  tensor([[3.2379],
#         [2.2984]], requires_grad=True)
# Step 684, theta:
#  tensor([[3.2392],
#         [2.2985]], requires_grad=True)
# Step 685, theta:
#  tensor([[3.2406],
#         [2.2986]], requires_grad=True)
# Step 686, theta:
#  tensor([[3.2419],
#         [2.2988]], requires_grad=True)
# Step 687, theta:
#  tensor([[3.2433],
#         [2.2989]], requires_grad=True)
# Step 688, theta:
#  tensor([[3.2446],
#         [2.2990]], requires_grad=True)
# Step 689, theta:
#  tensor([[3.2460],
#         [2.2991]], requires_grad=True)
# Step 690, theta:
#  tensor([[3.2473],
#         [2.2993]], requires_grad=True)
# Step 691, theta:
#  tensor([[3.2487],
#         [2.2994]], requires_grad=True)
# Step 692, theta:
#  tensor([[3.2500],
#         [2.2995]], requires_grad=True)
# Step 693, theta:
#  tensor([[3.2513],
#         [2.2996]], requires_grad=True)
# Step 694, theta:
#  tensor([[3.2527],
#         [2.2997]], requires_grad=True)
# Step 695, theta:
#  tensor([[3.2540],
#         [2.2999]], requires_grad=True)
# Step 696, theta:
#  tensor([[3.2553],
#         [2.3000]], requires_grad=True)
# Step 697, theta:
#  tensor([[3.2567],
#         [2.3001]], requires_grad=True)
# Step 698, theta:
#  tensor([[3.2580],
#         [2.3002]], requires_grad=True)
# Step 699, theta:
#  tensor([[3.2593],
#         [2.3004]], requires_grad=True)
# Step 700, theta:
#  tensor([[3.2606],
#         [2.3005]], requires_grad=True)
# Step 701, theta:
#  tensor([[3.2619],
#         [2.3006]], requires_grad=True)
# Step 702, theta:
#  tensor([[3.2633],
#         [2.3007]], requires_grad=True)
# Step 703, theta:
#  tensor([[3.2646],
#         [2.3009]], requires_grad=True)
# Step 704, theta:
#  tensor([[3.2659],
#         [2.3010]], requires_grad=True)
# Step 705, theta:
#  tensor([[3.2672],
#         [2.3011]], requires_grad=True)
# Step 706, theta:
#  tensor([[3.2685],
#         [2.3012]], requires_grad=True)
# Step 707, theta:
#  tensor([[3.2698],
#         [2.3014]], requires_grad=True)
# Step 708, theta:
#  tensor([[3.2711],
#         [2.3015]], requires_grad=True)
# Step 709, theta:
#  tensor([[3.2724],
#         [2.3016]], requires_grad=True)
# Step 710, theta:
#  tensor([[3.2737],
#         [2.3017]], requires_grad=True)
# Step 711, theta:
#  tensor([[3.2750],
#         [2.3019]], requires_grad=True)
# Step 712, theta:
#  tensor([[3.2762],
#         [2.3020]], requires_grad=True)
# Step 713, theta:
#  tensor([[3.2775],
#         [2.3021]], requires_grad=True)
# Step 714, theta:
#  tensor([[3.2788],
#         [2.3022]], requires_grad=True)
# Step 715, theta:
#  tensor([[3.2801],
#         [2.3024]], requires_grad=True)
# Step 716, theta:
#  tensor([[3.2814],
#         [2.3025]], requires_grad=True)
# Step 717, theta:
#  tensor([[3.2826],
#         [2.3026]], requires_grad=True)
# Step 718, theta:
#  tensor([[3.2839],
#         [2.3027]], requires_grad=True)
# Step 719, theta:
#  tensor([[3.2852],
#         [2.3029]], requires_grad=True)
# Step 720, theta:
#  tensor([[3.2865],
#         [2.3030]], requires_grad=True)
# Step 721, theta:
#  tensor([[3.2877],
#         [2.3031]], requires_grad=True)
# Step 722, theta:
#  tensor([[3.2890],
#         [2.3033]], requires_grad=True)
# Step 723, theta:
#  tensor([[3.2902],
#         [2.3034]], requires_grad=True)
# Step 724, theta:
#  tensor([[3.2915],
#         [2.3035]], requires_grad=True)
# Step 725, theta:
#  tensor([[3.2928],
#         [2.3036]], requires_grad=True)
# Step 726, theta:
#  tensor([[3.2940],
#         [2.3038]], requires_grad=True)
# Step 727, theta:
#  tensor([[3.2953],
#         [2.3039]], requires_grad=True)
# Step 728, theta:
#  tensor([[3.2965],
#         [2.3040]], requires_grad=True)
# Step 729, theta:
#  tensor([[3.2977],
#         [2.3042]], requires_grad=True)
# Step 730, theta:
#  tensor([[3.2990],
#         [2.3043]], requires_grad=True)
# Step 731, theta:
#  tensor([[3.3002],
#         [2.3044]], requires_grad=True)
# Step 732, theta:
#  tensor([[3.3015],
#         [2.3045]], requires_grad=True)
# Step 733, theta:
#  tensor([[3.3027],
#         [2.3047]], requires_grad=True)
# Step 734, theta:
#  tensor([[3.3039],
#         [2.3048]], requires_grad=True)
# Step 735, theta:
#  tensor([[3.3052],
#         [2.3049]], requires_grad=True)
# Step 736, theta:
#  tensor([[3.3064],
#         [2.3051]], requires_grad=True)
# Step 737, theta:
#  tensor([[3.3076],
#         [2.3052]], requires_grad=True)
# Step 738, theta:
#  tensor([[3.3088],
#         [2.3053]], requires_grad=True)
# Step 739, theta:
#  tensor([[3.3101],
#         [2.3054]], requires_grad=True)
# Step 740, theta:
#  tensor([[3.3113],
#         [2.3056]], requires_grad=True)
# Step 741, theta:
#  tensor([[3.3125],
#         [2.3057]], requires_grad=True)
# Step 742, theta:
#  tensor([[3.3137],
#         [2.3058]], requires_grad=True)
# Step 743, theta:
#  tensor([[3.3149],
#         [2.3060]], requires_grad=True)
# Step 744, theta:
#  tensor([[3.3161],
#         [2.3061]], requires_grad=True)
# Step 745, theta:
#  tensor([[3.3173],
#         [2.3062]], requires_grad=True)
# Step 746, theta:
#  tensor([[3.3185],
#         [2.3064]], requires_grad=True)
# Step 747, theta:
#  tensor([[3.3197],
#         [2.3065]], requires_grad=True)
# Step 748, theta:
#  tensor([[3.3209],
#         [2.3066]], requires_grad=True)
# Step 749, theta:
#  tensor([[3.3221],
#         [2.3067]], requires_grad=True)
# Step 750, theta:
#  tensor([[3.3233],
#         [2.3069]], requires_grad=True)
# Step 751, theta:
#  tensor([[3.3245],
#         [2.3070]], requires_grad=True)
# Step 752, theta:
#  tensor([[3.3257],
#         [2.3071]], requires_grad=True)
# Step 753, theta:
#  tensor([[3.3269],
#         [2.3073]], requires_grad=True)
# Step 754, theta:
#  tensor([[3.3281],
#         [2.3074]], requires_grad=True)
# Step 755, theta:
#  tensor([[3.3292],
#         [2.3075]], requires_grad=True)
# Step 756, theta:
#  tensor([[3.3304],
#         [2.3077]], requires_grad=True)
# Step 757, theta:
#  tensor([[3.3316],
#         [2.3078]], requires_grad=True)
# Step 758, theta:
#  tensor([[3.3328],
#         [2.3079]], requires_grad=True)
# Step 759, theta:
#  tensor([[3.3340],
#         [2.3081]], requires_grad=True)
# Step 760, theta:
#  tensor([[3.3351],
#         [2.3082]], requires_grad=True)
# Step 761, theta:
#  tensor([[3.3363],
#         [2.3083]], requires_grad=True)
# Step 762, theta:
#  tensor([[3.3375],
#         [2.3085]], requires_grad=True)
# Step 763, theta:
#  tensor([[3.3386],
#         [2.3086]], requires_grad=True)
# Step 764, theta:
#  tensor([[3.3398],
#         [2.3087]], requires_grad=True)
# Step 765, theta:
#  tensor([[3.3409],
#         [2.3088]], requires_grad=True)
# Step 766, theta:
#  tensor([[3.3421],
#         [2.3090]], requires_grad=True)
# Step 767, theta:
#  tensor([[3.3433],
#         [2.3091]], requires_grad=True)
# Step 768, theta:
#  tensor([[3.3444],
#         [2.3092]], requires_grad=True)
# Step 769, theta:
#  tensor([[3.3456],
#         [2.3094]], requires_grad=True)
# Step 770, theta:
#  tensor([[3.3467],
#         [2.3095]], requires_grad=True)
# Step 771, theta:
#  tensor([[3.3478],
#         [2.3096]], requires_grad=True)
# Step 772, theta:
#  tensor([[3.3490],
#         [2.3098]], requires_grad=True)
# Step 773, theta:
#  tensor([[3.3501],
#         [2.3099]], requires_grad=True)
# Step 774, theta:
#  tensor([[3.3513],
#         [2.3100]], requires_grad=True)
# Step 775, theta:
#  tensor([[3.3524],
#         [2.3102]], requires_grad=True)
# Step 776, theta:
#  tensor([[3.3535],
#         [2.3103]], requires_grad=True)
# Step 777, theta:
#  tensor([[3.3547],
#         [2.3104]], requires_grad=True)
# Step 778, theta:
#  tensor([[3.3558],
#         [2.3106]], requires_grad=True)
# Step 779, theta:
#  tensor([[3.3569],
#         [2.3107]], requires_grad=True)
# Step 780, theta:
#  tensor([[3.3580],
#         [2.3109]], requires_grad=True)
# Step 781, theta:
#  tensor([[3.3592],
#         [2.3110]], requires_grad=True)
# Step 782, theta:
#  tensor([[3.3603],
#         [2.3111]], requires_grad=True)
# Step 783, theta:
#  tensor([[3.3614],
#         [2.3113]], requires_grad=True)
# Step 784, theta:
#  tensor([[3.3625],
#         [2.3114]], requires_grad=True)
# Step 785, theta:
#  tensor([[3.3636],
#         [2.3115]], requires_grad=True)
# Step 786, theta:
#  tensor([[3.3648],
#         [2.3117]], requires_grad=True)
# Step 787, theta:
#  tensor([[3.3659],
#         [2.3118]], requires_grad=True)
# Step 788, theta:
#  tensor([[3.3670],
#         [2.3119]], requires_grad=True)
# Step 789, theta:
#  tensor([[3.3681],
#         [2.3121]], requires_grad=True)
# Step 790, theta:
#  tensor([[3.3692],
#         [2.3122]], requires_grad=True)
# Step 791, theta:
#  tensor([[3.3703],
#         [2.3123]], requires_grad=True)
# Step 792, theta:
#  tensor([[3.3714],
#         [2.3125]], requires_grad=True)
# Step 793, theta:
#  tensor([[3.3725],
#         [2.3126]], requires_grad=True)
# Step 794, theta:
#  tensor([[3.3736],
#         [2.3127]], requires_grad=True)
# Step 795, theta:
#  tensor([[3.3747],
#         [2.3129]], requires_grad=True)
# Step 796, theta:
#  tensor([[3.3757],
#         [2.3130]], requires_grad=True)
# Step 797, theta:
#  tensor([[3.3768],
#         [2.3132]], requires_grad=True)
# Step 798, theta:
#  tensor([[3.3779],
#         [2.3133]], requires_grad=True)
# Step 799, theta:
#  tensor([[3.3790],
#         [2.3134]], requires_grad=True)
# Step 800, theta:
#  tensor([[3.3801],
#         [2.3136]], requires_grad=True)
# Step 801, theta:
#  tensor([[3.3812],
#         [2.3137]], requires_grad=True)
# Step 802, theta:
#  tensor([[3.3822],
#         [2.3138]], requires_grad=True)
# Step 803, theta:
#  tensor([[3.3833],
#         [2.3140]], requires_grad=True)
# Step 804, theta:
#  tensor([[3.3844],
#         [2.3141]], requires_grad=True)
# Step 805, theta:
#  tensor([[3.3855],
#         [2.3142]], requires_grad=True)
# Step 806, theta:
#  tensor([[3.3865],
#         [2.3144]], requires_grad=True)
# Step 807, theta:
#  tensor([[3.3876],
#         [2.3145]], requires_grad=True)
# Step 808, theta:
#  tensor([[3.3887],
#         [2.3147]], requires_grad=True)
# Step 809, theta:
#  tensor([[3.3897],
#         [2.3148]], requires_grad=True)
# Step 810, theta:
#  tensor([[3.3908],
#         [2.3149]], requires_grad=True)
# Step 811, theta:
#  tensor([[3.3918],
#         [2.3151]], requires_grad=True)
# Step 812, theta:
#  tensor([[3.3929],
#         [2.3152]], requires_grad=True)
# Step 813, theta:
#  tensor([[3.3939],
#         [2.3153]], requires_grad=True)
# Step 814, theta:
#  tensor([[3.3950],
#         [2.3155]], requires_grad=True)
# Step 815, theta:
#  tensor([[3.3960],
#         [2.3156]], requires_grad=True)
# Step 816, theta:
#  tensor([[3.3971],
#         [2.3158]], requires_grad=True)
# Step 817, theta:
#  tensor([[3.3981],
#         [2.3159]], requires_grad=True)
# Step 818, theta:
#  tensor([[3.3992],
#         [2.3160]], requires_grad=True)
# Step 819, theta:
#  tensor([[3.4002],
#         [2.3162]], requires_grad=True)
# Step 820, theta:
#  tensor([[3.4013],
#         [2.3163]], requires_grad=True)
# Step 821, theta:
#  tensor([[3.4023],
#         [2.3164]], requires_grad=True)
# Step 822, theta:
#  tensor([[3.4033],
#         [2.3166]], requires_grad=True)
# Step 823, theta:
#  tensor([[3.4044],
#         [2.3167]], requires_grad=True)
# Step 824, theta:
#  tensor([[3.4054],
#         [2.3169]], requires_grad=True)
# Step 825, theta:
#  tensor([[3.4064],
#         [2.3170]], requires_grad=True)
# Step 826, theta:
#  tensor([[3.4075],
#         [2.3171]], requires_grad=True)
# Step 827, theta:
#  tensor([[3.4085],
#         [2.3173]], requires_grad=True)
# Step 828, theta:
#  tensor([[3.4095],
#         [2.3174]], requires_grad=True)
# Step 829, theta:
#  tensor([[3.4105],
#         [2.3176]], requires_grad=True)
# Step 830, theta:
#  tensor([[3.4115],
#         [2.3177]], requires_grad=True)
# Step 831, theta:
#  tensor([[3.4126],
#         [2.3178]], requires_grad=True)
# Step 832, theta:
#  tensor([[3.4136],
#         [2.3180]], requires_grad=True)
# Step 833, theta:
#  tensor([[3.4146],
#         [2.3181]], requires_grad=True)
# Step 834, theta:
#  tensor([[3.4156],
#         [2.3182]], requires_grad=True)
# Step 835, theta:
#  tensor([[3.4166],
#         [2.3184]], requires_grad=True)
# Step 836, theta:
#  tensor([[3.4176],
#         [2.3185]], requires_grad=True)
# Step 837, theta:
#  tensor([[3.4186],
#         [2.3187]], requires_grad=True)
# Step 838, theta:
#  tensor([[3.4196],
#         [2.3188]], requires_grad=True)
# Step 839, theta:
#  tensor([[3.4206],
#         [2.3189]], requires_grad=True)
# 840
# [7.7485857009887695, 7.722414493560791, 7.694252014160156, 7.666036128997803, 7.6379194259643555, 7.609915256500244, 7.582023620605469, 7.554244041442871, 7.526575565338135, 7.49901819229126, 7.4715728759765625, 7.444235801696777, 7.417010307312012, 7.389892578125, 7.362885475158691, 7.335986137390137, 7.309195518493652, 7.2825117111206055, 7.255936622619629, 7.229466438293457, 7.203103542327881, 7.176846504211426, 7.150694847106934, 7.1246490478515625, 7.0987067222595215, 7.072869300842285, 7.047135353088379, 7.021504878997803, 6.995977878570557, 6.970552921295166, 6.945230007171631, 6.920009613037109, 6.894889831542969, 6.869871616363525, 6.8449530601501465, 6.82013463973999, 6.795416831970215, 6.770796775817871, 6.74627685546875, 6.721855163574219, 6.697532653808594, 6.673306465148926, 6.649178504943848, 6.625146389007568, 6.6012115478515625, 6.5773725509643555, 6.553629398345947, 6.5299811363220215, 6.506427764892578, 6.482969760894775, 6.4596052169799805, 6.436335563659668, 6.413159370422363, 6.39007568359375, 6.3670854568481445, 6.344186305999756, 6.321379661560059, 6.2986650466918945, 6.276041030883789, 6.253508567810059, 6.23106575012207, 6.208713054656982, 6.1864519119262695, 6.164278030395508, 6.1421942710876465, 6.1201982498168945, 6.098290920257568, 6.076472282409668, 6.054740905761719, 6.0330963134765625, 6.011538505554199, 5.990067958831787, 5.96868371963501, 5.947384834289551, 5.926172256469727, 5.9050445556640625, 5.8840012550354, 5.863042831420898, 5.84216833114624, 5.821377277374268, 5.8006696701049805, 5.780045986175537, 5.759505271911621, 5.739046573638916, 5.718669891357422, 5.6983747482299805, 5.67816162109375, 5.658029079437256, 5.6379780769348145, 5.618006706237793, 5.598116397857666, 5.578304290771484, 5.558573246002197, 5.538920879364014, 5.519347190856934, 5.499852657318115, 5.480436325073242, 5.461097717285156, 5.441836357116699, 5.422652721405029, 5.40354585647583, 5.384516716003418, 5.365562438964844, 5.346684455871582, 5.327882766723633, 5.309156894683838, 5.290505886077881, 5.271928787231445, 5.253427505493164, 5.234999656677246, 5.216646671295166, 5.198367118835449, 5.1801605224609375, 5.162026882171631, 5.143965721130371, 5.125977516174316, 5.108061790466309, 5.090217590332031, 5.072444438934326, 5.05474328994751, 5.037112712860107, 5.019554138183594, 5.0020647048950195, 4.984644889831543, 4.967296600341797, 4.950016498565674, 4.932806968688965, 4.915665626525879, 4.898592948913574, 4.881589412689209, 4.864653587341309, 4.847785949707031, 4.8309855461120605, 4.814253330230713, 4.7975873947143555, 4.7809882164001465, 4.764455795288086, 4.747990131378174, 4.73159122467041, 4.715256690979004, 4.69898796081543, 4.682784080505371, 4.666646480560303, 4.650572776794434, 4.634564399719238, 4.618618965148926, 4.602738380432129, 4.586920261383057, 4.5711669921875, 4.555476188659668, 4.539848327636719, 4.524282932281494, 4.508780479431152, 4.493339538574219, 4.477961540222168, 4.462643623352051, 4.447388648986816, 4.432193756103516, 4.417059898376465, 4.401987075805664, 4.386975288391113, 4.37202262878418, 4.357131004333496, 4.342297554016113, 4.3275251388549805, 4.312811374664307, 4.298156261444092, 4.283559799194336, 4.269021987915039, 4.254542350769043, 4.240120887756348, 4.225757122039795, 4.211451530456543, 4.197202682495117, 4.183010578155518, 4.168875694274902, 4.154797554016113, 4.14077615737915, 4.1268110275268555, 4.112901210784912, 4.099047660827637, 4.085249900817871, 4.071506977081299, 4.05781888961792, 4.044185161590576, 4.030606269836426, 4.017082691192627, 4.003612518310547, 3.9901962280273438, 3.976834535598755, 3.963526487350464, 3.950270891189575, 3.9370689392089844, 3.923919200897217, 3.910822629928589, 3.8977787494659424, 3.884786605834961, 3.871847152709961, 3.8589587211608887, 3.8461222648620605, 3.8333373069763184, 3.820603132247925, 3.807919979095459, 3.7952873706817627, 3.7827060222625732, 3.7701752185821533, 3.757694721221924, 3.7452645301818848, 3.7328834533691406, 3.720551729 ...
